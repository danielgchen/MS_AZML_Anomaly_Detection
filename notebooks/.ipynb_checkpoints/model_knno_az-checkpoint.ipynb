# %%
## SET UP AZUREML DETAILS
# imports
from azureml.core.authentication import InteractiveLoginAuthentication
from azureml.core import Workspace, Environment, Experiment, Dataset, ScriptRunConfig

# set up workspace
config_path = '../utils/config.json'
tenant_id = '72f988bf-86f1-41af-91ab-2d7cd011db47'  # this is outputted post `az login`
interactive_auth = InteractiveLoginAuthentication(tenant_id=tenant_id)  # create log-in object
ws = Workspace.from_config(path=config_path, auth=interactive_auth)  # link workspace

# set up environment
# - obtain environment.yml from `conda env export > environment.yml`
env_name = 'SampleEnv'
env_path = '../utils/environment.yml'
env = Environment.from_conda_specification(name=env_name, file_path=env_path)

# set up experiment
experiment_name = 'IsolationForestSample'
exp = Experiment(workspace=ws, name=experiment_name)

# set up dataset
dataset_path = 'http://kdd.ics.uci.edu/databases/kddcup99/kddcup.data_10_percent.gz'
ds = Dataset.File.from_files(dataset_path)

# set up run
src_dir = '../src'
src_name = 'azure_isolation_forest.py'
compute_name = 'WorkspaceCompute'
arguments = ['--data-path', ds.as_mount()]
src = ScriptRunConfig(source_directory=src_dir, script=src_name, compute_target=compute_name,
                      environment=env, arguments=arguments)
# Out:
# Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.

# %%
## SUBMIT THE RUN
from azureml.widgets import RunDetails

run = exp.submit(src)  # submit it to the azureml platform
RunDetails(run).show()  # monitor the steps
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…

# %%
# show the outputs
run.wait_for_completion(show_output=True)
# Out:
# RunId: IsolationForestSample_1619669764_dff88b21
# Web View: https://ml.azure.com/experiments/IsolationForestSample/runs/IsolationForestSample_1619669764_dff88b21?wsid=/subscriptions/6560575d-fa06-4e7d-95fb-f962e74efd7a/resourcegroups/UW_AnomalyDetection/workspaces/AnomalyDetection
#
# Streaming azureml-logs/55_azureml-execution-tvmps_177c7c6f6e31a5082b2bfa5ea10a85c82f2ac4b4ff3b45d98b97f8561c755fdd_d.txt
# ========================================================================================================================
#
# 2021-04-29T04:19:11Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/isolationforestsample_1619669764_dff88b21/mounts/workspaceblobstore
# 2021-04-29T04:19:11Z Starting output-watcher...
# 2021-04-29T04:19:12Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-04-29T04:19:12Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-04-29T04:19:12Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_4539de3ccb169db6707c8cade7afe14c
# 4007a89234b4: Pulling fs layer
# 5dfa26c6b9c9: Pulling fs layer
# 0ba7bf18aa40: Pulling fs layer
# 4c6ec688ebe3: Pulling fs layer
# 574f361512d6: Pulling fs layer
# db4d1e2d7079: Pulling fs layer
# e544ee0f522d: Pulling fs layer
# c655136086be: Pulling fs layer
# 2ec37f44090c: Pulling fs layer
# 5fba3bd4a2c4: Pulling fs layer
# 7e0ea9d0a1ab: Pulling fs layer
# da005f826951: Pulling fs layer
# ac4e1c91b241: Pulling fs layer
# efb648489c68: Pulling fs layer
# e5e2bb35fef1: Pulling fs layer
# 41f64f9d12ca: Pulling fs layer
# 404e390f8ac9: Pulling fs layer
# 00d1c09f699a: Pulling fs layer
# 5fba3bd4a2c4: Waiting
# 7e0ea9d0a1ab: Waiting
# da005f826951: Waiting
# ac4e1c91b241: Waiting
# efb648489c68: Waiting
# e5e2bb35fef1: Waiting
# 41f64f9d12ca: Waiting
# 404e390f8ac9: Waiting
# 00d1c09f699a: Waiting
# 574f361512d6: Waiting
# db4d1e2d7079: Waiting
# e544ee0f522d: Waiting
# c655136086be: Waiting
# 2ec37f44090c: Waiting
# 4c6ec688ebe3: Waiting
# 5dfa26c6b9c9: Verifying Checksum
# 5dfa26c6b9c9: Download complete
# 0ba7bf18aa40: Verifying Checksum
# 0ba7bf18aa40: Download complete
# 4c6ec688ebe3: Verifying Checksum
# 4c6ec688ebe3: Download complete
# db4d1e2d7079: Verifying Checksum
# db4d1e2d7079: Download complete
# 4007a89234b4: Verifying Checksum
# 4007a89234b4: Download complete
# 574f361512d6: Verifying Checksum
# 574f361512d6: Download complete
# e544ee0f522d: Verifying Checksum
# e544ee0f522d: Download complete
# c655136086be: Verifying Checksum
# c655136086be: Download complete
# 5fba3bd4a2c4: Verifying Checksum
# 5fba3bd4a2c4: Download complete
# da005f826951: Verifying Checksum
# da005f826951: Download complete
# 7e0ea9d0a1ab: Verifying Checksum
# 7e0ea9d0a1ab: Download complete
# ac4e1c91b241: Verifying Checksum
# ac4e1c91b241: Download complete
# 2ec37f44090c: Verifying Checksum
# 2ec37f44090c: Download complete
# 41f64f9d12ca: Verifying Checksum
# 41f64f9d12ca: Download complete
# e5e2bb35fef1: Verifying Checksum
# e5e2bb35fef1: Download complete
# 404e390f8ac9: Verifying Checksum
# 404e390f8ac9: Download complete
# efb648489c68: Verifying Checksum
# efb648489c68: Download complete
# 00d1c09f699a: Download complete
# 4007a89234b4: Pull complete
# 5dfa26c6b9c9: Pull complete
# 0ba7bf18aa40: Pull complete
# 4c6ec688ebe3: Pull complete
# 574f361512d6: Pull complete
# db4d1e2d7079: Pull complete
# e544ee0f522d: Pull complete
# c655136086be: Pull complete
# 2ec37f44090c: Pull complete
# 5fba3bd4a2c4: Pull complete
# 7e0ea9d0a1ab: Pull complete
# da005f826951: Pull complete
# ac4e1c91b241: Pull complete
#
# Streaming azureml-logs/65_job_prep-tvmps_177c7c6f6e31a5082b2bfa5ea10a85c82f2ac4b4ff3b45d98b97f8561c755fdd_d.txt
# ===============================================================================================================
#
# [2021-04-29T04:21:07.112808] Entering job preparation.
# [2021-04-29T04:21:08.029256] Starting job preparation.
# [2021-04-29T04:21:08.029628] Extracting the control code.
# [2021-04-29T04:21:08.051655] fetching and extracting the control code on master node.
# [2021-04-29T04:21:08.051711] Starting extract_project.
# [2021-04-29T04:21:08.051761] Starting to extract zip file.
# [2021-04-29T04:21:08.622343] Finished extracting zip file.
# [2021-04-29T04:21:08.802580] Using urllib.request Python 3.0 or later
# [2021-04-29T04:21:08.802651] Start fetching snapshots.
# [2021-04-29T04:21:08.802697] Start fetching snapshot.
# [2021-04-29T04:21:08.802711] Retrieving project from snapshot: 8784ca50-422a-4ec2-b5da-d71ad3512faa
# Starting the daemon thread to refresh tokens in background for process with pid = 54
# [2021-04-29T04:21:09.200563] Finished fetching snapshot.
# [2021-04-29T04:21:09.200612] Finished fetching snapshots.
# [2021-04-29T04:21:09.200626] Finished extract_project.
# [2021-04-29T04:21:09.218367] Finished fetching and extracting the control code.
# [2021-04-29T04:21:09.225961] Start run_history_prep.
# [2021-04-29T04:21:09.310568] Job preparation is complete.
# [2021-04-29T04:21:09.310741] Entering Data Context Managers in Sidecar
# [2021-04-29T04:21:09.311745] Running Sidecar prep cmd...
# [2021-04-29T04:21:09.793942] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/isolationforestsample_1619669764_dff88b21/mounts/workspaceblobstore/azureml/IsolationForestSample_1619669764_dff88b21
# [2021-04-29T04:21:09.795013] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.26.0 azureml-dataprep==2.14.2. Session id: c1af6783-efc6-4d2b-9860-dcd6ab36f1a5. Run id: IsolationForestSample_1619669764_dff88b21.
# Processing 'input__ff1c759a'.
# Processing dataset FileDataset
# {
#   "source": [
#     "http://kdd.ics.uci.edu/databases/kddcup99/kddcup.data_10_percent.gz"
#   ],
#   "definition": [
#     "GetFiles"
#   ],
#   "registration": {
#     "id": "d4023713-1cdf-4f6e-8670-7fd800a85d2c",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='AnomalyDetection', subscription_id='6560575d-fa06-4e7d-95fb-f962e74efd7a', resource_group='UW_AnomalyDetection')"
#   }
# }
# Mounting input__ff1c759a to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/isolationforestsample_1619669764_dff88b21/wd/tmpm8j_il2b.
# Mounted input__ff1c759a to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/isolationforestsample_1619669764_dff88b21/wd/tmpm8j_il2b as single file.
# Exit __enter__ of DatasetContextManager
# Set Dataset input__ff1c759a's target path to /mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/isolationforestsample_1619669764_dff88b21/wd/tmpm8j_il2b/kddcup.data_10_percent.gz
# [2021-04-29T04:21:23.563026] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-04-29T04:21:24.017279] Ran Sidecar prep cmd.
# [2021-04-29T04:21:24.017369] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/75_job_post-tvmps_177c7c6f6e31a5082b2bfa5ea10a85c82f2ac4b4ff3b45d98b97f8561c755fdd_d.txt
# ===============================================================================================================
#
# [2021-04-29T04:23:39.178428] Entering job release
# [2021-04-29T04:23:40.113676] Starting job release
# [2021-04-29T04:23:40.114469] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 279
# [2021-04-29T04:23:40.115366] job release stage : upload_datastore starting...
# [2021-04-29T04:23:40.117812] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-04-29T04:23:40.119507] job release stage : execute_job_release starting...
# [2021-04-29T04:23:40.120002] job release stage : copy_batchai_cached_logs starting...
# [2021-04-29T04:23:40.120429] job release stage : copy_batchai_cached_logs completed...
# [2021-04-29T04:23:40.192472] Entering context manager injector.
# [2021-04-29T04:23:40.194749] job release stage : upload_datastore completed...
# [2021-04-29T04:23:40.251923] job release stage : send_run_telemetry starting...
# [2021-04-29T04:23:40.329805] job release stage : execute_job_release completed...
# [2021-04-29T04:23:40.493422] get vm size and vm region successfully.
# [2021-04-29T04:23:40.527144] get compute meta data successfully.
# [2021-04-29T04:23:40.882124] post artifact meta request successfully.
# [2021-04-29T04:23:40.920666] upload compute record artifact successfully.
# [2021-04-29T04:23:40.920784] job release stage : send_run_telemetry completed...
# [2021-04-29T04:23:40.921476] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-04-29T04:23:40.921634] Running Sidecar release cmd...
# [2021-04-29T04:23:40.935407] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/isolationforestsample_1619669764_dff88b21/mounts/workspaceblobstore/azureml/IsolationForestSample_1619669764_dff88b21
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/isolationforestsample_1619669764_dff88b21/wd/tmpm8j_il2b.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/isolationforestsample_1619669764_dff88b21/wd/tmpm8j_il2b.
# Exit __exit__ of DatasetContextManager
# [2021-04-29T04:23:41.022243] Removing absolute paths from host...
# [2021-04-29T04:23:41.030400] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-04-29T04:23:41.486562] Ran Sidecar release cmd.
# [2021-04-29T04:23:41.486677] Job release is complete
#
# Execution Summary
# =================
# RunId: IsolationForestSample_1619669764_dff88b21
# Web View: https://ml.azure.com/experiments/IsolationForestSample/runs/IsolationForestSample_1619669764_dff88b21?wsid=/subscriptions/6560575d-fa06-4e7d-95fb-f962e74efd7a/resourcegroups/UW_AnomalyDetection/workspaces/AnomalyDetection
# {'runId': 'IsolationForestSample_1619669764_dff88b21',
#  'target': 'WorkspaceCompute',
#  'status': 'Completed',
#  'startTimeUtc': '2021-04-29T04:18:58.915786Z',
#  'endTimeUtc': '2021-04-29T04:23:58.643583Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': 'bfaee966-b2a2-444d-ba2a-de4ca303c29a',
#   'azureml.git.repository_uri': 'https://github.com/danielgchen/MS_AZML_Anomaly_Detection.git',
#   'mlflow.source.git.repoURL': 'https://github.com/danielgchen/MS_AZML_Anomaly_Detection.git',
#   'azureml.git.branch': 'master',
#   'mlflow.source.git.branch': 'master',
#   'azureml.git.commit': 'de8c0bfe9ef5d093bbf7763db632dca36cee9440',
#   'mlflow.source.git.commit': 'de8c0bfe9ef5d093bbf7763db632dca36cee9440',
#   'azureml.git.dirty': 'True',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [{'dataset': {'id': 'd4023713-1cdf-4f6e-8670-7fd800a85d2c'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input__ff1c759a', 'mechanism': 'Mount'}}],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'azure_isolation_forest.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--data-path', 'DatasetConsumptionConfig:input__ff1c759a'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'WorkspaceCompute',
#   'dataReferences': {},
#   'data': {'input__ff1c759a': {'dataLocation': {'dataset': {'id': 'd4023713-1cdf-4f6e-8670-7fd800a85d2c',
#       'name': None,
#       'version': None},
#      'dataPath': None,
#      'url': None},
#     'mechanism': 'Mount',
#     'environmentVariableName': 'input__ff1c759a',
#     'pathOnCompute': None,
#     'overwrite': False}},
#   'outputData': {},
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'SampleEnv',
#    'version': 'Autosave_2021-04-01T00:44:37Z_2f4c34ca',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['defaults', 'anaconda', 'conda-forge'],
#      'dependencies': ['python=3.7',
#       'pip',
#       {'pip': ['mlflow',
#         'matplotlib',
#         'seaborn',
#         'sklearn',
#         'azureml-mlflow',
#         'azureml-dataprep']}],
#      'name': 'azureml_f32d401024a650ffb8b10221a412f480'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210129.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': None,
#    'imageVersion': None,
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {}},
#  'logFiles': {'azureml-logs/55_azureml-execution-tvmps_177c7c6f6e31a5082b2bfa5ea10a85c82f2ac4b4ff3b45d98b97f8561c755fdd_d.txt': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1619669764_dff88b21/azureml-logs/55_azureml-execution-tvmps_177c7c6f6e31a5082b2bfa5ea10a85c82f2ac4b4ff3b45d98b97f8561c755fdd_d.txt?sv=2019-02-02&sr=b&sig=i4LjBxv0jq%2B9Dc%2Bs%2F04lwHHotR9n1eo4s3m2WZG20Ek%3D&st=2021-04-29T04%3A13%3A48Z&se=2021-04-29T12%3A23%3A48Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_177c7c6f6e31a5082b2bfa5ea10a85c82f2ac4b4ff3b45d98b97f8561c755fdd_d.txt': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1619669764_dff88b21/azureml-logs/65_job_prep-tvmps_177c7c6f6e31a5082b2bfa5ea10a85c82f2ac4b4ff3b45d98b97f8561c755fdd_d.txt?sv=2019-02-02&sr=b&sig=oU35MyuIajfaiPrbENDP%2Fsuu3diPgMvOCCxpz4GfIj4%3D&st=2021-04-29T04%3A13%3A49Z&se=2021-04-29T12%3A23%3A49Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1619669764_dff88b21/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=WrpgzzrBl9X%2F5sY25MNX9SjL5sJqF5IokhDAkmgreiA%3D&st=2021-04-29T04%3A13%3A49Z&se=2021-04-29T12%3A23%3A49Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_177c7c6f6e31a5082b2bfa5ea10a85c82f2ac4b4ff3b45d98b97f8561c755fdd_d.txt': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1619669764_dff88b21/azureml-logs/75_job_post-tvmps_177c7c6f6e31a5082b2bfa5ea10a85c82f2ac4b4ff3b45d98b97f8561c755fdd_d.txt?sv=2019-02-02&sr=b&sig=iBNKD2uaVGt3KGNVdKa6EYsLDeUZnrWUTL4v6C5I5sg%3D&st=2021-04-29T04%3A13%3A49Z&se=2021-04-29T12%3A23%3A49Z&sp=r',
#   'azureml-logs/process_info.json': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1619669764_dff88b21/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=td1aRdcr0YUJk2eieNnEV%2BJ2w%2FDvedn2T6AGmDENw1E%3D&st=2021-04-29T04%3A13%3A49Z&se=2021-04-29T12%3A23%3A49Z&sp=r',
#   'azureml-logs/process_status.json': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1619669764_dff88b21/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=dcWO%2BZennEUNeS3h1tWa90bGOut9%2Bay%2BI562L6gKelE%3D&st=2021-04-29T04%3A13%3A49Z&se=2021-04-29T12%3A23%3A49Z&sp=r',
#   'logs/azureml/78_azureml.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1619669764_dff88b21/logs/azureml/78_azureml.log?sv=2019-02-02&sr=b&sig=6UJcKRcTW6yThRwwNnDC6K6bJHiX1sHLGKya15c4IzI%3D&st=2021-04-29T04%3A13%3A48Z&se=2021-04-29T12%3A23%3A48Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1619669764_dff88b21/logs/azureml/dataprep/backgroundProcess.log?sv=2019-02-02&sr=b&sig=Vx43y2E%2FPKNoMWx3Z4DHEaMmoQNfHoY6Qc5Wa4Svxbs%3D&st=2021-04-29T04%3A13%3A49Z&se=2021-04-29T12%3A23%3A49Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess_Telemetry.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1619669764_dff88b21/logs/azureml/dataprep/backgroundProcess_Telemetry.log?sv=2019-02-02&sr=b&sig=l1hJPOVcsTTEc1iDLMKk15zAsJIw0TN8BOLLuH1HwZE%3D&st=2021-04-29T04%3A13%3A49Z&se=2021-04-29T12%3A23%3A49Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1619669764_dff88b21/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=niZNwAvwP%2F5Qv%2F5hTs4tb76F%2FX5M8KFoiljlU%2BzVqj8%3D&st=2021-04-29T04%3A13%3A49Z&se=2021-04-29T12%3A23%3A49Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1619669764_dff88b21/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=a%2FRdxUvlwKjfusTLMDdoFZn9g3XNZ%2BIc8V%2FeXGJXZ94%3D&st=2021-04-29T04%3A13%3A49Z&se=2021-04-29T12%3A23%3A49Z&sp=r',
#   'logs/azureml/sidecar/tvmps_177c7c6f6e31a5082b2bfa5ea10a85c82f2ac4b4ff3b45d98b97f8561c755fdd_d/all.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1619669764_dff88b21/logs/azureml/sidecar/tvmps_177c7c6f6e31a5082b2bfa5ea10a85c82f2ac4b4ff3b45d98b97f8561c755fdd_d/all.log?sv=2019-02-02&sr=b&sig=FqyPjLYafT9cyvH4d5sRdCR1BsMJXTgAQjJBbO3p1uA%3D&st=2021-04-29T04%3A13%3A49Z&se=2021-04-29T12%3A23%3A49Z&sp=r',
#   'logs/azureml/sidecar/tvmps_177c7c6f6e31a5082b2bfa5ea10a85c82f2ac4b4ff3b45d98b97f8561c755fdd_d/task.enter_contexts.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1619669764_dff88b21/logs/azureml/sidecar/tvmps_177c7c6f6e31a5082b2bfa5ea10a85c82f2ac4b4ff3b45d98b97f8561c755fdd_d/task.enter_contexts.log?sv=2019-02-02&sr=b&sig=oxCjOXYfv33b0EdALa4sN542V7R%2Bd%2BEUpMuREbc3KQo%3D&st=2021-04-29T04%3A13%3A49Z&se=2021-04-29T12%3A23%3A49Z&sp=r',
#   'logs/azureml/sidecar/tvmps_177c7c6f6e31a5082b2bfa5ea10a85c82f2ac4b4ff3b45d98b97f8561c755fdd_d/task.exit_contexts.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1619669764_dff88b21/logs/azureml/sidecar/tvmps_177c7c6f6e31a5082b2bfa5ea10a85c82f2ac4b4ff3b45d98b97f8561c755fdd_d/task.exit_contexts.log?sv=2019-02-02&sr=b&sig=eG7FWAkyt9mpUSn4FjkCa1U2KavIoakB8DwzIX2%2Fp5Y%3D&st=2021-04-29T04%3A13%3A49Z&se=2021-04-29T12%3A23%3A49Z&sp=r'},
#  'submittedBy': 'Daniel Chen'}
