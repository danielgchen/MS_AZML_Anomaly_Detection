# %%
# !cat ../utils/config.json
# Out:
# {
#     "subscription_id": "6560575d-fa06-4e7d-95fb-f962e74efd7a",
#     "resource_group": "UW_AnomalyDetection",
#     "workspace_name": "AnomalyDetection"
# }

# %%
# !cat ../utils/environment.yml
# Out:
# name: SampleEnv
# channels:
#   - defaults
#   - anaconda
#   - conda-forge
# dependencies:
#   - python=3.7
#   - pip
#   - pip:
#     - mlflow
#     - matplotlib
#     - seaborn
#     - sklearn
#     - azureml-mlflow
#     - azureml-dataprep

# %%
# !cat ../src/azure_isolation_forest.py
# Out:
# import mlflow
# import random
# import argparse
# import numpy as np
# import pandas as pd
# from sklearn.ensemble import IsolationForest
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import f1_score
#
# # helper functions
#
#
# # main method
# if __name__ == "__main__":
#     # set up argument parser
#     parser = argparse.ArgumentParser()
#     parser.add_argument('--data-path', type=str, help='path to the dataset')
#     args = parser.parse_args()
#
#     # read the data
#     df = pd.read_csv(args.data_path, index_col=0)
#     print(df.head())
# #     # read the data
# #     df = pd.read_csv('../data/kddcup.data_0_1_percent.csv', index_col=0)
#
# #     # filter labels
# #     labels = df['41']  # get labels
# #     label_counts = labels.value_counts()  # n-obs / label
# #     mask = label_counts > df.shape[0] * 0.05  # label must encompass > 5% of the data
# #     valid_labels = label_counts.index[mask]  # get passing labels
# #     print(f'Passing labels = {valid_labels.tolist()}')
# #     df = df[df['41'].isin(valid_labels)]
# #     labels = df['41']  # redefine labels
#
# #     # split data
# #     # - if it's an intrusion
# #     mask_normal, mask_anomaly = labels=='normal.', labels!='normal.'  # get masks
# #     df_normal, df_anomaly = df[mask_normal], df[mask_anomaly]  # subset data
# #     # - set seed
# #     random_state = 0
# #     random.seed(random_state)
# #     np.random.seed(0)
# #     # - normal ml splitting
# #     X, y = df_normal.select_dtypes(['number']), labels[mask_normal]  # last column is label
# #     params = train_test_split(X, y, test_size=1/4, random_state=random_state, shuffle=True, stratify=y)
# #     X_train, X_test, y_train, y_test = params
# #     # - anomaly ml splitting
# #     X_test_anomaly, y_test_anomaly = df_anomaly.select_dtypes(['number']), labels[mask_anomaly]
#
# #     # fit model - utilizes "density" splitting such that majority of data stays together
# #     model = IsolationForest(random_state=0)
# #     model.fit(X_train)
#
# #     # compute f1 scores
# #     # - normal - train
# #     f1_normal_train = f1_score([1]*X_train.shape[0], model.predict(X_train), pos_label=1)
# #     # - normal - test
# #     f1_normal_test = f1_score([1]*X_test.shape[0], model.predict(X_test), pos_label=1)
# #     # - anomaly - smurf
# #     mask_smurf = y_test_anomaly=='smurf.'
# #     f1_intrusion_smurf = f1_score([-1]*sum(mask_smurf), model.predict(X_test_anomaly[mask_smurf]), pos_label=-1)
# #     # - anomaly - neptune
# #     mask_neptune = y_test_anomaly=='neptune.'
# #     f1_intrusion_neptune = f1_score([-1]*sum(mask_neptune), model.predict(X_test_anomaly[mask_neptune]), pos_label=-1)
# #     # - anomaly - all
# #     f1_intrusion = f1_score([-1]*X_test_anomaly.shape[0], model.predict(X_test_anomaly), pos_label=-1)
#
# #     # construct dataframe
# #     f1_scores = [f1_normal_train, f1_normal_test, f1_intrusion_smurf, f1_intrusion_neptune, f1_intrusion]
# #     categories = ['Normal-Train', 'Normal-Test', 'Intrusion-Smurf', 'Intrusion-Neptune', 'Intrusion']
# #     plot_df = pd.DataFrame([f1_scores, categories], index=['F1 Score', 'Category']).T
# #     plot_df = plot_df.sort_values('F1 Score')
# #     print(plot_df)
# # #     # log metrics
# # #     mlflow.log_metric('F1-Scores', plot_df)

# %%
## SET UP AZUREML DETAILS
# imports
from azureml.core.authentication import InteractiveLoginAuthentication
from azureml.core import Workspace, Environment, Experiment, Dataset, ScriptRunConfig

# set up workspace
config_path = '../utils/config.json'
tenant_id = '72f988bf-86f1-41af-91ab-2d7cd011db47'  # this is outputted post `az login`
interactive_auth = InteractiveLoginAuthentication(tenant_id=tenant_id)  # create log-in object
ws = Workspace.from_config(path=config_path, auth=interactive_auth)  # link workspace

# set up environment
# - obtain environment.yml from `conda env export > environment.yml`
env_name = 'SampleEnv'
env_path = '../utils/environment.yml'
env = Environment.from_conda_specification(name=env_name, file_path=env_path)

# set up experiment
experiment_name = 'IsolationForestSample'
exp = Experiment(workspace=ws, name=experiment_name)

# set up dataset
dataset_path = 'http://kdd.ics.uci.edu/databases/kddcup99/kddcup.data_10_percent.gz'
ds = Dataset.File.from_files(dataset_path)

# set up run
src_dir = '../src'
src_name = 'azure_isolation_forest.py'
compute_name = 'WorkspaceCompute'
arguments = ['--data-path', ds.as_mount()]
src = ScriptRunConfig(source_directory=src_dir, script=src_name, compute_target=compute_name,
                      environment=env, arguments=arguments)
# Out:
# Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.

# %%
## SUBMIT THE RUN
from azureml.widgets import RunDetails

run = exp.submit(src)  # submit it to the azureml platform
RunDetails(run).show()  # monitor the steps
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…

# %%
# show the outputs
run.wait_for_completion(show_output=True)
# Out:
# RunId: IsolationForestSample_1617239084_43e798cf
# Web View: https://ml.azure.com/experiments/IsolationForestSample/runs/IsolationForestSample_1617239084_43e798cf?wsid=/subscriptions/6560575d-fa06-4e7d-95fb-f962e74efd7a/resourcegroups/UW_AnomalyDetection/workspaces/AnomalyDetection
#
# Streaming azureml-logs/55_azureml-execution-tvmps_9a19018db32945838db2d68ed9900a0e31da94d13a20d7c6950cde31febb7b4c_d.txt
# ========================================================================================================================
#
# 2021-04-01T01:10:41Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/isolationforestsample_1617239084_43e798cf/mounts/workspaceblobstore
# 2021-04-01T01:10:43Z Starting output-watcher...
# 2021-04-01T01:10:43Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-04-01T01:10:43Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-04-01T01:10:43Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_25e6cb78b6103af17d967d864cd0a9b0
# 4007a89234b4: Pulling fs layer
# 5dfa26c6b9c9: Pulling fs layer
# 0ba7bf18aa40: Pulling fs layer
# 4c6ec688ebe3: Pulling fs layer
# 574f361512d6: Pulling fs layer
# db4d1e2d7079: Pulling fs layer
# e544ee0f522d: Pulling fs layer
# 4c6ec688ebe3: Waiting
# 574f361512d6: Waiting
# db4d1e2d7079: Waiting
# c655136086be: Pulling fs layer
# 2ec37f44090c: Pulling fs layer
# 5fba3bd4a2c4: Pulling fs layer
# 7e0ea9d0a1ab: Pulling fs layer
# da005f826951: Pulling fs layer
# 8cb4864d0b34: Pulling fs layer
# e544ee0f522d: Waiting
# c655136086be: Waiting
# 2ec37f44090c: Waiting
# 5fba3bd4a2c4: Waiting
# 7e0ea9d0a1ab: Waiting
# da005f826951: Waiting
# 259045429d68: Pulling fs layer
# 52e2c2f9ed6b: Pulling fs layer
# dce7b0b331c8: Pulling fs layer
# 1b9c2568c22e: Pulling fs layer
# 235a4a737d5b: Pulling fs layer
# 259045429d68: Waiting
# 52e2c2f9ed6b: Waiting
# dce7b0b331c8: Waiting
# 1b9c2568c22e: Waiting
# 235a4a737d5b: Waiting
# 5dfa26c6b9c9: Verifying Checksum
# 5dfa26c6b9c9: Download complete
# 0ba7bf18aa40: Verifying Checksum
# 0ba7bf18aa40: Download complete
# 4c6ec688ebe3: Verifying Checksum
# 4c6ec688ebe3: Download complete
# db4d1e2d7079: Verifying Checksum
# db4d1e2d7079: Download complete
# 574f361512d6: Verifying Checksum
# 574f361512d6: Download complete
# e544ee0f522d: Verifying Checksum
# e544ee0f522d: Download complete
# 4007a89234b4: Verifying Checksum
# 4007a89234b4: Download complete
# 5fba3bd4a2c4: Verifying Checksum
# 5fba3bd4a2c4: Download complete
# 7e0ea9d0a1ab: Verifying Checksum
# 7e0ea9d0a1ab: Download complete
# da005f826951: Verifying Checksum
# da005f826951: Download complete
# 8cb4864d0b34: Verifying Checksum
# 8cb4864d0b34: Download complete
# c655136086be: Verifying Checksum
# c655136086be: Download complete
# 52e2c2f9ed6b: Verifying Checksum
# 52e2c2f9ed6b: Download complete
# 2ec37f44090c: Verifying Checksum
# 2ec37f44090c: Download complete
# dce7b0b331c8: Verifying Checksum
# dce7b0b331c8: Download complete
# 1b9c2568c22e: Verifying Checksum
# 1b9c2568c22e: Download complete
# 235a4a737d5b: Verifying Checksum
# 235a4a737d5b: Download complete
# 259045429d68: Verifying Checksum
# 259045429d68: Download complete
# 4007a89234b4: Pull complete
# 5dfa26c6b9c9: Pull complete
# 0ba7bf18aa40: Pull complete
# 4c6ec688ebe3: Pull complete
# 574f361512d6: Pull complete
# db4d1e2d7079: Pull complete
# e544ee0f522d: Pull complete
# c655136086be: Pull complete
# 2ec37f44090c: Pull complete
# 5fba3bd4a2c4: Pull complete
# 7e0ea9d0a1ab: Pull complete
# da005f826951: Pull complete
# 8cb4864d0b34: Pull complete
#
# Streaming azureml-logs/65_job_prep-tvmps_9a19018db32945838db2d68ed9900a0e31da94d13a20d7c6950cde31febb7b4c_d.txt
# ===============================================================================================================
#
# [2021-04-01T01:12:33.214550] Entering job preparation.
# [2021-04-01T01:12:33.972384] Starting job preparation.
# [2021-04-01T01:12:33.972426] Extracting the control code.
# [2021-04-01T01:12:33.996012] fetching and extracting the control code on master node.
# [2021-04-01T01:12:33.996067] Starting extract_project.
# [2021-04-01T01:12:33.996111] Starting to extract zip file.
# [2021-04-01T01:12:34.867834] Finished extracting zip file.
# [2021-04-01T01:12:35.127507] Using urllib.request Python 3.0 or later
# [2021-04-01T01:12:35.127572] Start fetching snapshots.
# [2021-04-01T01:12:35.127622] Start fetching snapshot.
# [2021-04-01T01:12:35.127643] Retrieving project from snapshot: 26b28ab9-0b1a-4f8b-9350-3cb89bfee645
# Starting the daemon thread to refresh tokens in background for process with pid = 55
# [2021-04-01T01:12:35.888806] Finished fetching snapshot.
# [2021-04-01T01:12:35.888845] Finished fetching snapshots.
# [2021-04-01T01:12:35.888860] Finished extract_project.
# [2021-04-01T01:12:35.934440] Finished fetching and extracting the control code.
# [2021-04-01T01:12:35.943381] Start run_history_prep.
# [2021-04-01T01:12:36.274616] Job preparation is complete.
# [2021-04-01T01:12:36.274784] Entering Data Context Managers in Sidecar
# [2021-04-01T01:12:36.275585] Running Sidecar prep cmd...
# [2021-04-01T01:12:36.362065] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/isolationforestsample_1617239084_43e798cf/mounts/workspaceblobstore/azureml/IsolationForestSample_1617239084_43e798cf
# [2021-04-01T01:12:36.362896] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.23.0 azureml-dataprep==2.10.3. Session id: 268bd768-f017-4f0e-876e-d74904d1da0d. Run id: IsolationForestSample_1617239084_43e798cf.
# Processing 'input__109c1a88'.
# Processing dataset FileDataset
# {
#   "source": [
#     "http://kdd.ics.uci.edu/databases/kddcup99/kddcup.data_10_percent.gz"
#   ],
#   "definition": [
#     "GetFiles"
#   ],
#   "registration": {
#     "id": "d4023713-1cdf-4f6e-8670-7fd800a85d2c",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='AnomalyDetection', subscription_id='6560575d-fa06-4e7d-95fb-f962e74efd7a', resource_group='UW_AnomalyDetection')"
#   }
# }
# Mounting input__109c1a88 to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/isolationforestsample_1617239084_43e798cf/wd/tmp7r5idihe.
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (cryptography 3.2.1 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2')).
# Mounted input__109c1a88 to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/isolationforestsample_1617239084_43e798cf/wd/tmp7r5idihe as single file.
# Exit __enter__ of DatasetContextManager
# Set Dataset input__109c1a88's target path to /mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/isolationforestsample_1617239084_43e798cf/wd/tmp7r5idihe/kddcup.data_10_percent.gz
# Starting the daemon thread to refresh tokens in background for process with pid = 1
# [2021-04-01T01:12:48.642144] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (cryptography 3.2.1 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2')).
# [2021-04-01T01:12:50.379465] Ran Sidecar prep cmd.
# [2021-04-01T01:12:50.379559] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/75_job_post-tvmps_9a19018db32945838db2d68ed9900a0e31da94d13a20d7c6950cde31febb7b4c_d.txt
# ===============================================================================================================
#
# [2021-04-01T01:15:07.612542] Entering job release
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (cryptography 3.2.1 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2')).
# [2021-04-01T01:15:08.443041] Starting job release
# [2021-04-01T01:15:08.443668] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 275
# [2021-04-01T01:15:08.446130] job release stage : upload_datastore starting...
# [2021-04-01T01:15:08.446846] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-04-01T01:15:08.446945] job release stage : execute_job_release starting...
# [2021-04-01T01:15:08.447109] job release stage : copy_batchai_cached_logs starting...
# [2021-04-01T01:15:08.447166] job release stage : copy_batchai_cached_logs completed...
# [2021-04-01T01:15:08.540215] Entering context manager injector.
# [2021-04-01T01:15:08.541718] job release stage : upload_datastore completed...
# [2021-04-01T01:15:08.555534] job release stage : send_run_telemetry starting...
# [2021-04-01T01:15:08.746092] job release stage : execute_job_release completed...
# [2021-04-01T01:15:08.828754] get vm size and vm region successfully.
# [2021-04-01T01:15:08.848722] get compute meta data successfully.
# [2021-04-01T01:15:09.263905] post artifact meta request successfully.
# [2021-04-01T01:15:09.334837] upload compute record artifact successfully.
# [2021-04-01T01:15:09.596277] job release stage : send_run_telemetry completed...
# [2021-04-01T01:15:09.597619] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-04-01T01:15:09.598003] Running Sidecar release cmd...
# [2021-04-01T01:15:09.609411] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/isolationforestsample_1617239084_43e798cf/mounts/workspaceblobstore/azureml/IsolationForestSample_1617239084_43e798cf
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/isolationforestsample_1617239084_43e798cf/wd/tmp7r5idihe.
# fuse: failed to unmount /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/isolationforestsample_1617239084_43e798cf/wd/tmp7r5idihe: Invalid argument
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/isolationforestsample_1617239084_43e798cf/wd/tmp7r5idihe.
# Exit __exit__ of DatasetContextManager
# [2021-04-01T01:15:09.722317] Removing absolute paths from host...
# [2021-04-01T01:15:09.900437] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-04-01T01:15:10.799409] Ran Sidecar release cmd.
# [2021-04-01T01:15:10.799540] Job release is complete
# Execution Summary
# =================
# RunId: IsolationForestSample_1617239084_43e798cf
# Web View: https://ml.azure.com/experiments/IsolationForestSample/runs/IsolationForestSample_1617239084_43e798cf?wsid=/subscriptions/6560575d-fa06-4e7d-95fb-f962e74efd7a/resourcegroups/UW_AnomalyDetection/workspaces/AnomalyDetection
# {'runId': 'IsolationForestSample_1617239084_43e798cf',
#  'target': 'WorkspaceCompute',
#  'status': 'Completed',
#  'startTimeUtc': '2021-04-01T01:10:46.142735Z',
#  'endTimeUtc': '2021-04-01T01:15:22.322323Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': '7d19d761-f753-49bd-a31b-392c8b3a3651',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [{'dataset': {'id': 'd4023713-1cdf-4f6e-8670-7fd800a85d2c'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input__109c1a88', 'mechanism': 'Mount'}}],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'azure_isolation_forest.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--data-path', 'DatasetConsumptionConfig:input__109c1a88'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'WorkspaceCompute',
#   'dataReferences': {},
#   'data': {'input__109c1a88': {'dataLocation': {'dataset': {'id': 'd4023713-1cdf-4f6e-8670-7fd800a85d2c',
#       'name': None,
#       'version': None},
#      'dataPath': None},
#     'mechanism': 'Mount',
#     'environmentVariableName': 'input__109c1a88',
#     'pathOnCompute': None,
#     'overwrite': False}},
#   'outputData': {},
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'SampleEnv',
#    'version': 'Autosave_2021-04-01T00:44:37Z_2f4c34ca',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['defaults', 'anaconda', 'conda-forge'],
#      'dependencies': ['python=3.7',
#       'pip',
#       {'pip': ['mlflow',
#         'matplotlib',
#         'seaborn',
#         'sklearn',
#         'azureml-mlflow',
#         'azureml-dataprep']}],
#      'name': 'azureml_f32d401024a650ffb8b10221a412f480'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210129.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': None,
#    'imageVersion': None,
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {}},
#  'logFiles': {'azureml-logs/55_azureml-execution-tvmps_9a19018db32945838db2d68ed9900a0e31da94d13a20d7c6950cde31febb7b4c_d.txt': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1617239084_43e798cf/azureml-logs/55_azureml-execution-tvmps_9a19018db32945838db2d68ed9900a0e31da94d13a20d7c6950cde31febb7b4c_d.txt?sv=2019-02-02&sr=b&sig=vJlcAiXXGV211eBNwF0YsPzkkKJM%2FWEjTk5S39HN9lQ%3D&st=2021-04-01T01%3A05%3A14Z&se=2021-04-01T09%3A15%3A14Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_9a19018db32945838db2d68ed9900a0e31da94d13a20d7c6950cde31febb7b4c_d.txt': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1617239084_43e798cf/azureml-logs/65_job_prep-tvmps_9a19018db32945838db2d68ed9900a0e31da94d13a20d7c6950cde31febb7b4c_d.txt?sv=2019-02-02&sr=b&sig=p3jrT11sW%2FBWOyBFT6jng5lVbFJUFSSLNG4dtVR2GPU%3D&st=2021-04-01T01%3A05%3A14Z&se=2021-04-01T09%3A15%3A14Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1617239084_43e798cf/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=k%2BxxZT%2BnVaSTASvuGy%2FW7%2BhROJ68tYKSFrhx5ni0mXg%3D&st=2021-04-01T01%3A05%3A14Z&se=2021-04-01T09%3A15%3A14Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_9a19018db32945838db2d68ed9900a0e31da94d13a20d7c6950cde31febb7b4c_d.txt': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1617239084_43e798cf/azureml-logs/75_job_post-tvmps_9a19018db32945838db2d68ed9900a0e31da94d13a20d7c6950cde31febb7b4c_d.txt?sv=2019-02-02&sr=b&sig=rTE1uIE%2FS%2FE8y4LsNanWMbdm2J41cIWgzuxWYiFGWLM%3D&st=2021-04-01T01%3A05%3A14Z&se=2021-04-01T09%3A15%3A14Z&sp=r',
#   'azureml-logs/process_info.json': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1617239084_43e798cf/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=wrLUeUD1V9nIBkXve6WIQ00RgW22F9snJ7LcrRwmNQM%3D&st=2021-04-01T01%3A05%3A14Z&se=2021-04-01T09%3A15%3A14Z&sp=r',
#   'azureml-logs/process_status.json': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1617239084_43e798cf/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=reoiMMAn%2FFRvHy033Xld7pQ9G5g%2FdnzicLpkExl02Fc%3D&st=2021-04-01T01%3A05%3A14Z&se=2021-04-01T09%3A15%3A14Z&sp=r',
#   'logs/azureml/78_azureml.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1617239084_43e798cf/logs/azureml/78_azureml.log?sv=2019-02-02&sr=b&sig=%2Fl39olyUbWX14dFTook%2FrWU4k6RLsL%2Bgqk2sByLwO8U%3D&st=2021-04-01T01%3A05%3A14Z&se=2021-04-01T09%3A15%3A14Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1617239084_43e798cf/logs/azureml/dataprep/backgroundProcess.log?sv=2019-02-02&sr=b&sig=DVmoAj1rJOF4yfAIzbG85xNnYXURUSbZAgyeIewp0Mo%3D&st=2021-04-01T01%3A05%3A14Z&se=2021-04-01T09%3A15%3A14Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess_Telemetry.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1617239084_43e798cf/logs/azureml/dataprep/backgroundProcess_Telemetry.log?sv=2019-02-02&sr=b&sig=Anj0kORRH06YrTgqi2byd%2BrnnnH0%2Bs6MTFR1Fa5KAD0%3D&st=2021-04-01T01%3A05%3A14Z&se=2021-04-01T09%3A15%3A14Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1617239084_43e798cf/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=bo9Q0AEGOhON2LxO%2BIjWQf02iobeFT0q9dtdOefAvWM%3D&st=2021-04-01T01%3A05%3A14Z&se=2021-04-01T09%3A15%3A14Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1617239084_43e798cf/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=zSawSB%2FlrQUbRHsrkPC%2BlAn8cnSkSSVMgTVrHoCrHJc%3D&st=2021-04-01T01%3A05%3A14Z&se=2021-04-01T09%3A15%3A14Z&sp=r',
#   'logs/azureml/sidecar/tvmps_9a19018db32945838db2d68ed9900a0e31da94d13a20d7c6950cde31febb7b4c_d/all.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1617239084_43e798cf/logs/azureml/sidecar/tvmps_9a19018db32945838db2d68ed9900a0e31da94d13a20d7c6950cde31febb7b4c_d/all.log?sv=2019-02-02&sr=b&sig=49CL6LXYPTXXV4jqaclOY9IDKnhv6YejCsSpP%2FJ9VUI%3D&st=2021-04-01T01%3A05%3A14Z&se=2021-04-01T09%3A15%3A14Z&sp=r',
#   'logs/azureml/sidecar/tvmps_9a19018db32945838db2d68ed9900a0e31da94d13a20d7c6950cde31febb7b4c_d/task.enter_contexts.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1617239084_43e798cf/logs/azureml/sidecar/tvmps_9a19018db32945838db2d68ed9900a0e31da94d13a20d7c6950cde31febb7b4c_d/task.enter_contexts.log?sv=2019-02-02&sr=b&sig=kqdIcNdFXrEGMYj%2B5O%2BrkH%2BwheBxcaosYTO4KIuwRpo%3D&st=2021-04-01T01%3A05%3A14Z&se=2021-04-01T09%3A15%3A14Z&sp=r',
#   'logs/azureml/sidecar/tvmps_9a19018db32945838db2d68ed9900a0e31da94d13a20d7c6950cde31febb7b4c_d/task.exit_contexts.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.IsolationForestSample_1617239084_43e798cf/logs/azureml/sidecar/tvmps_9a19018db32945838db2d68ed9900a0e31da94d13a20d7c6950cde31febb7b4c_d/task.exit_contexts.log?sv=2019-02-02&sr=b&sig=yVpxl2paIckscRlS0xlpuofxH2titZQFX3ojb4%2FDo3M%3D&st=2021-04-01T01%3A05%3A14Z&se=2021-04-01T09%3A15%3A14Z&sp=r'},
#  'submittedBy': 'Daniel Chen'}
