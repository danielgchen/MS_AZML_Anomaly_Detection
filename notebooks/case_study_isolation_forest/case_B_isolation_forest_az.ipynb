# %%
## SET UP AZUREML DETAILS
# imports
from azureml.core.authentication import InteractiveLoginAuthentication
from azureml.core import Workspace, Environment, Experiment, Dataset, ScriptRunConfig

# set up workspace
config_path = '../../utils/config_GPU.json'
tenant_id = '72f988bf-86f1-41af-91ab-2d7cd011db47'  # this is outputted post `az login`
interactive_auth = InteractiveLoginAuthentication(tenant_id=tenant_id)  # create log-in object
ws = Workspace.from_config(path=config_path, auth=interactive_auth)  # link workspace

# set up environment
# - obtain environment.yml from `conda env export > environment.yml`
env_name = 'SampleEnv'
env_path = '../../utils/environment.yml'
env = Environment.from_conda_specification(name=env_name, file_path=env_path)

# set up experiment
experiment_name = 'AnomalyDetection'
exp = Experiment(workspace=ws, name=experiment_name)

# set up dataset
dataset_path = 'http://kdd.ics.uci.edu/databases/kddcup99/kddcup.data_10_percent.gz'
ds = Dataset.File.from_files(dataset_path)

# set up run
src_dir = '../../src/case_study_isolation_forest'
src_name = 'azure_isolation_forest_case_B.py'
compute_name = 'gpu-compute-one'
arguments = ['--data-path', ds.as_mount()]
src = ScriptRunConfig(source_directory=src_dir, script=src_name, compute_target=compute_name,
                      environment=env, arguments=arguments)

# %%
## SUBMIT THE RUN
from azureml.widgets import RunDetails

run = exp.submit(src)  # submit it to the azureml platform
RunDetails(run).show()  # monitor the steps
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…

# %%
# show the outputs
run.wait_for_completion(show_output=True)
# Out:
# RunId: AnomalyDetection_1622158971_1f171416
# Web View: https://ml.azure.com/experiments/AnomalyDetection/runs/AnomalyDetection_1622158971_1f171416?wsid=/subscriptions/6560575d-fa06-4e7d-95fb-f962e74efd7a/resourcegroups/UW_AnomalyDetection/workspaces/AnomalyDetection
#
# Streaming azureml-logs/55_azureml-execution-tvmps_33c03fa3f303a2d67271aba56f1f519b11dc078dcc42c7912f8d653f76fe6343_d.txt
# ========================================================================================================================
#
# 2021-05-27T23:46:55Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/anomalydetection_1622158971_1f171416/mounts/workspaceblobstore
# 2021-05-27T23:46:56Z Starting output-watcher...
# 2021-05-27T23:46:56Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-05-27T23:46:58Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-05-27T23:46:58Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_fe4afc798de401edfb76dc27a38b1703
# 92473f7ef455: Pulling fs layer
# fb52bde70123: Pulling fs layer
# 64788f86be3f: Pulling fs layer
# 33f6d5f2e001: Pulling fs layer
# eeb715f1b6ae: Pulling fs layer
# fe519cf36537: Pulling fs layer
# 58ff99196c15: Pulling fs layer
# 9b13f06a8eff: Pulling fs layer
# 2d4e93adbf58: Pulling fs layer
# 6ee7c3767844: Pulling fs layer
# 62cfc3ccb8ab: Pulling fs layer
# 4a7af9d757ee: Pulling fs layer
# 9e11d437728f: Pulling fs layer
# 3506c910620f: Pulling fs layer
# afe6352c52c2: Pulling fs layer
# 45d886309004: Pulling fs layer
# 2ce19e789040: Pulling fs layer
# f2a2950e1ed4: Pulling fs layer
# 33f6d5f2e001: Waiting
# eeb715f1b6ae: Waiting
# fe519cf36537: Waiting
# 58ff99196c15: Waiting
# 9b13f06a8eff: Waiting
# 2d4e93adbf58: Waiting
# 6ee7c3767844: Waiting
# 62cfc3ccb8ab: Waiting
# 4a7af9d757ee: Waiting
# 9e11d437728f: Waiting
# 3506c910620f: Waiting
# afe6352c52c2: Waiting
# 45d886309004: Waiting
# 2ce19e789040: Waiting
# f2a2950e1ed4: Waiting
# 64788f86be3f: Verifying Checksum
# 64788f86be3f: Download complete
# fb52bde70123: Verifying Checksum
# fb52bde70123: Download complete
# 33f6d5f2e001: Verifying Checksum
# 33f6d5f2e001: Download complete
# fe519cf36537: Verifying Checksum
# fe519cf36537: Download complete
# 92473f7ef455: Verifying Checksum
# 92473f7ef455: Download complete
# 58ff99196c15: Download complete
# eeb715f1b6ae: Verifying Checksum
# eeb715f1b6ae: Download complete
# 6ee7c3767844: Verifying Checksum
# 6ee7c3767844: Download complete
# 62cfc3ccb8ab: Verifying Checksum
# 62cfc3ccb8ab: Download complete
# 9b13f06a8eff: Verifying Checksum
# 9b13f06a8eff: Download complete
# 4a7af9d757ee: Verifying Checksum
# 4a7af9d757ee: Download complete
# 2d4e93adbf58: Verifying Checksum
# 2d4e93adbf58: Download complete
# 9e11d437728f: Verifying Checksum
# 9e11d437728f: Download complete
# 45d886309004: Verifying Checksum
# 45d886309004: Download complete
# afe6352c52c2: Verifying Checksum
# afe6352c52c2: Download complete
# 2ce19e789040: Verifying Checksum
# 2ce19e789040: Download complete
# f2a2950e1ed4: Verifying Checksum
# f2a2950e1ed4: Download complete
# 3506c910620f: Verifying Checksum
# 3506c910620f: Download complete
# 92473f7ef455: Pull complete
# fb52bde70123: Pull complete
# 64788f86be3f: Pull complete
# 33f6d5f2e001: Pull complete
# eeb715f1b6ae: Pull complete
# fe519cf36537: Pull complete
# 58ff99196c15: Pull complete
# 9b13f06a8eff: Pull complete
# 2d4e93adbf58: Pull complete
# 6ee7c3767844: Pull complete
# 62cfc3ccb8ab: Pull complete
# 4a7af9d757ee: Pull complete
# 9e11d437728f: Pull complete
# 3506c910620f: Pull complete
# afe6352c52c2: Pull complete
# 45d886309004: Pull complete
# 2ce19e789040: Pull complete
# f2a2950e1ed4: Pull complete
# Digest: sha256:5224cd9c4e07c9304c90193ab084da3cf8643e81065eef4d81c2c4029c58248c
# Status: Downloaded newer image for viennaglobal.azurecr.io/azureml/azureml_fe4afc798de401edfb76dc27a38b1703:latest
# viennaglobal.azurecr.io/azureml/azureml_fe4afc798de401edfb76dc27a38b1703:latest
# 2021-05-27T23:48:39Z Check if container anomalydetection_1622158971_1f171416_DataSidecar already exist exited with 0,
#
#
# Streaming azureml-logs/65_job_prep-tvmps_33c03fa3f303a2d67271aba56f1f519b11dc078dcc42c7912f8d653f76fe6343_d.txt
# ===============================================================================================================
#
# [2021-05-27T23:49:05.017050] Entering job preparation.
# [2021-05-27T23:49:05.769872] Starting job preparation.
# [2021-05-27T23:49:05.769917] Extracting the control code.
# [2021-05-27T23:49:05.795051] fetching and extracting the control code on master node.
# [2021-05-27T23:49:05.795099] Starting extract_project.
# [2021-05-27T23:49:05.795140] Starting to extract zip file.
# [2021-05-27T23:49:06.376079] Finished extracting zip file.
# [2021-05-27T23:49:06.532407] Using urllib.request Python 3.0 or later
# [2021-05-27T23:49:06.532508] Start fetching snapshots.
# [2021-05-27T23:49:06.532558] Start fetching snapshot.
# [2021-05-27T23:49:06.532590] Retrieving project from snapshot: aad864e9-2763-4d25-aafb-5e9cd7fe1834
# Starting the daemon thread to refresh tokens in background for process with pid = 53
# [2021-05-27T23:49:07.194742] Finished fetching snapshot.
# [2021-05-27T23:49:07.195025] Finished fetching snapshots.
# [2021-05-27T23:49:07.195179] Finished extract_project.
# [2021-05-27T23:49:07.210649] Finished fetching and extracting the control code.
# [2021-05-27T23:49:07.218553] Start run_history_prep.
# [2021-05-27T23:49:07.270649] Job preparation is complete.
# [2021-05-27T23:49:07.270797] Entering Data Context Managers in Sidecar
# [2021-05-27T23:49:07.271509] Running Sidecar prep cmd...
# [2021-05-27T23:49:07.701276] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/anomalydetection_1622158971_1f171416/mounts/workspaceblobstore/azureml/AnomalyDetection_1622158971_1f171416
# [2021-05-27T23:49:07.702305] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.28.0 azureml-dataprep==2.16.0. Session id: 874f1e7e-4bb8-4e4b-8aa9-7d3e2adf892e. Run id: AnomalyDetection_1622158971_1f171416.
# Processing 'input__272f77a6'.
# Processing dataset FileDataset
# {
#   "source": [
#     "http://kdd.ics.uci.edu/databases/kddcup99/kddcup.data_10_percent.gz"
#   ],
#   "definition": [
#     "GetFiles"
#   ],
#   "registration": {
#     "id": "d4023713-1cdf-4f6e-8670-7fd800a85d2c",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='AnomalyDetection', subscription_id='6560575d-fa06-4e7d-95fb-f962e74efd7a', resource_group='UW_AnomalyDetection')"
#   }
# }
# Mounting input__272f77a6 to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/anomalydetection_1622158971_1f171416/wd/input__272f77a6_d4023713-1cdf-4f6e-8670-7fd800a85d2c.
# Mounted input__272f77a6 to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/anomalydetection_1622158971_1f171416/wd/input__272f77a6_d4023713-1cdf-4f6e-8670-7fd800a85d2c as single file.
# Exit __enter__ of DatasetContextManager
# Set Dataset input__272f77a6's target path to /mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/anomalydetection_1622158971_1f171416/wd/input__272f77a6_d4023713-1cdf-4f6e-8670-7fd800a85d2c/kddcup.data_10_percent.gz
# [2021-05-27T23:49:20.517911] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-05-27T23:49:21.255733] Ran Sidecar prep cmd.
# [2021-05-27T23:49:21.255828] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/75_job_post-tvmps_33c03fa3f303a2d67271aba56f1f519b11dc078dcc42c7912f8d653f76fe6343_d.txt
# ===============================================================================================================
#
# [2021-05-27T23:51:46.335231] Entering job release
# [2021-05-27T23:51:47.879812] Starting job release
# [2021-05-27T23:51:47.880455] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 290
# [2021-05-27T23:51:47.881489] job release stage : upload_datastore starting...
# [2021-05-27T23:51:47.883854] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-05-27T23:51:47.884071] job release stage : execute_job_release starting...
# [2021-05-27T23:51:47.884374] job release stage : copy_batchai_cached_logs starting...
# [2021-05-27T23:51:47.884575] job release stage : copy_batchai_cached_logs completed...
# [2021-05-27T23:51:47.997507] Entering context manager injector.
# [2021-05-27T23:51:48.019179] job release stage : send_run_telemetry starting...
# [2021-05-27T23:51:48.037249] job release stage : execute_job_release completed...
# [2021-05-27T23:51:48.057428] job release stage : upload_datastore completed...
# [2021-05-27T23:51:48.319694] get vm size and vm region successfully.
# [2021-05-27T23:51:48.356972] get compute meta data successfully.
# [2021-05-27T23:51:48.830588] post artifact meta request successfully.
# [2021-05-27T23:51:48.863907] upload compute record artifact successfully.
# [2021-05-27T23:51:48.864019] job release stage : send_run_telemetry completed...
# [2021-05-27T23:51:48.864834] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-05-27T23:51:48.865207] Running Sidecar release cmd...
# [2021-05-27T23:51:48.887383] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/anomalydetection_1622158971_1f171416/mounts/workspaceblobstore/azureml/AnomalyDetection_1622158971_1f171416
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/anomalydetection_1622158971_1f171416/wd/input__272f77a6_d4023713-1cdf-4f6e-8670-7fd800a85d2c.
# fuse: failed to unmount /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/anomalydetection_1622158971_1f171416/wd/input__272f77a6_d4023713-1cdf-4f6e-8670-7fd800a85d2c: Invalid argument
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/anomalydetection_1622158971_1f171416/wd/input__272f77a6_d4023713-1cdf-4f6e-8670-7fd800a85d2c.
# Exit __exit__ of DatasetContextManager
# [2021-05-27T23:51:48.977424] Removing absolute paths from host...
# [2021-05-27T23:51:48.988902] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-05-27T23:51:49.342408] Ran Sidecar release cmd.
# [2021-05-27T23:51:49.342729] Job release is complete
#
# Execution Summary
# =================
# RunId: AnomalyDetection_1622158971_1f171416
# Web View: https://ml.azure.com/experiments/AnomalyDetection/runs/AnomalyDetection_1622158971_1f171416?wsid=/subscriptions/6560575d-fa06-4e7d-95fb-f962e74efd7a/resourcegroups/UW_AnomalyDetection/workspaces/AnomalyDetection
# {'runId': 'AnomalyDetection_1622158971_1f171416',
#  'target': 'WorkspaceCompute',
#  'status': 'Completed',
#  'startTimeUtc': '2021-05-27T23:46:57.729728Z',
#  'endTimeUtc': '2021-05-27T23:52:00.026183Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': '8680b32f-8890-4ab2-898b-4bf2f6ce2cc3',
#   'azureml.git.repository_uri': 'https://github.com/danielgchen/MS_AZML_Anomaly_Detection.git',
#   'mlflow.source.git.repoURL': 'https://github.com/danielgchen/MS_AZML_Anomaly_Detection.git',
#   'azureml.git.branch': 'master',
#   'mlflow.source.git.branch': 'master',
#   'azureml.git.commit': '462d3f28acee8b4e44f9d33ad513084a9d4360b5',
#   'mlflow.source.git.commit': '462d3f28acee8b4e44f9d33ad513084a9d4360b5',
#   'azureml.git.dirty': 'True',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json',
#   'azureml.datastoreId': '/subscriptions/6560575d-fa06-4e7d-95fb-f962e74efd7a/resourceGroups/UW_AnomalyDetection/providers/Microsoft.MachineLearningServices/workspaces/AnomalyDetection/datastores/anomalydetecti4902467972_azureml',
#   'mlflow.param.key.bootstrap': 'False',
#   'mlflow.param.key.contamination': 'auto',
#   'mlflow.param.key.max_features': '50',
#   'mlflow.param.key.max_samples': '256',
#   'mlflow.param.key.n_estimators': '50',
#   'mlflow.param.key.n_jobs': 'None',
#   'mlflow.param.key.random_state': '0',
#   'mlflow.param.key.verbose': '0',
#   'mlflow.param.key.warm_start': 'False'},
#  'inputDatasets': [{'dataset': {'id': 'd4023713-1cdf-4f6e-8670-7fd800a85d2c'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input__272f77a6', 'mechanism': 'Mount'}}],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'azure_isolation_forest_case_B.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--data-path', 'DatasetConsumptionConfig:input__272f77a6'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'WorkspaceCompute',
#   'dataReferences': {},
#   'data': {'input__272f77a6': {'dataLocation': {'dataset': {'id': 'd4023713-1cdf-4f6e-8670-7fd800a85d2c',
#       'name': None,
#       'version': None},
#      'dataPath': None,
#      'uri': None},
#     'mechanism': 'Mount',
#     'environmentVariableName': 'input__272f77a6',
#     'pathOnCompute': None,
#     'overwrite': False}},
#   'outputData': {},
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'SampleEnv',
#    'version': 'Autosave_2021-05-24T17:31:07Z_04a5f2d2',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['defaults', 'anaconda', 'conda-forge'],
#      'dependencies': ['python=3.8',
#       'pip',
#       {'pip': ['sklearn',
#         'anomatools',
#         'dtaidistance',
#         'azureml-dataprep',
#         'azureml-mlflow',
#         'mlflow',
#         'matplotlib',
#         'seaborn']}],
#      'name': 'azureml_85d71eb43e0985ef03c127d2ca5e6476'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210129.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': None,
#    'imageVersion': None,
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {}},
#  'logFiles': {'azureml-logs/55_azureml-execution-tvmps_33c03fa3f303a2d67271aba56f1f519b11dc078dcc42c7912f8d653f76fe6343_d.txt': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622158971_1f171416/azureml-logs/55_azureml-execution-tvmps_33c03fa3f303a2d67271aba56f1f519b11dc078dcc42c7912f8d653f76fe6343_d.txt?sv=2019-02-02&sr=b&sig=x0iMzr304LQxC6gvLqhmoI0M%2B4PxTyr1hGB4A00Es4M%3D&st=2021-05-27T23%3A42%3A05Z&se=2021-05-28T07%3A52%3A05Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_33c03fa3f303a2d67271aba56f1f519b11dc078dcc42c7912f8d653f76fe6343_d.txt': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622158971_1f171416/azureml-logs/65_job_prep-tvmps_33c03fa3f303a2d67271aba56f1f519b11dc078dcc42c7912f8d653f76fe6343_d.txt?sv=2019-02-02&sr=b&sig=WwsDm7bJq4G0g4jzJjurFCNorMrlhU9ovaREEPGVa4Q%3D&st=2021-05-27T23%3A42%3A05Z&se=2021-05-28T07%3A52%3A05Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622158971_1f171416/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=zbvGhCwEkZEG7JFM%2FG2XnkFwD4qDLsa%2BuFi%2BAe7fzIc%3D&st=2021-05-27T23%3A42%3A05Z&se=2021-05-28T07%3A52%3A05Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_33c03fa3f303a2d67271aba56f1f519b11dc078dcc42c7912f8d653f76fe6343_d.txt': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622158971_1f171416/azureml-logs/75_job_post-tvmps_33c03fa3f303a2d67271aba56f1f519b11dc078dcc42c7912f8d653f76fe6343_d.txt?sv=2019-02-02&sr=b&sig=oIpZWNyLwFi2DyP%2BRBmLf7lMraQELzc%2BqPnPfxtZVWo%3D&st=2021-05-27T23%3A42%3A05Z&se=2021-05-28T07%3A52%3A05Z&sp=r',
#   'azureml-logs/process_info.json': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622158971_1f171416/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=cnlacCOLS5iWRwetJ5sejyB30LBCr1qrKM2oBFuJxmI%3D&st=2021-05-27T23%3A42%3A05Z&se=2021-05-28T07%3A52%3A05Z&sp=r',
#   'azureml-logs/process_status.json': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622158971_1f171416/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=R%2BTt2W%2FqPJus2hPo6V%2FEh4FFbbIvRtt8WsI1dJKYvgM%3D&st=2021-05-27T23%3A42%3A06Z&se=2021-05-28T07%3A52%3A06Z&sp=r',
#   'logs/azureml/81_azureml.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622158971_1f171416/logs/azureml/81_azureml.log?sv=2019-02-02&sr=b&sig=OuEGx%2FZR91tx0pZc2gOP46lg4VpCZ4WXYfdim662eHc%3D&st=2021-05-27T23%3A42%3A05Z&se=2021-05-28T07%3A52%3A05Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622158971_1f171416/logs/azureml/dataprep/backgroundProcess.log?sv=2019-02-02&sr=b&sig=qWH%2BBLXpwhLNBBzkGqIhyGE3cZuftGsR3mGmI0o%2F9xk%3D&st=2021-05-27T23%3A42%3A06Z&se=2021-05-28T07%3A52%3A06Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess_Telemetry.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622158971_1f171416/logs/azureml/dataprep/backgroundProcess_Telemetry.log?sv=2019-02-02&sr=b&sig=TqpBoSteRViCnnUON7gIoWveip0V8nxfPvIYSmjSy1I%3D&st=2021-05-27T23%3A42%3A06Z&se=2021-05-28T07%3A52%3A06Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622158971_1f171416/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=M8tZPLyjULUUt45tf%2Bg3gfUaUgJ%2B4JwASuLV4uAMisk%3D&st=2021-05-27T23%3A42%3A06Z&se=2021-05-28T07%3A52%3A06Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622158971_1f171416/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=%2Fhl8gwbr9ca3B1%2Bi3eSKNIjSbGzudHXxMEsPO6Iy1fw%3D&st=2021-05-27T23%3A42%3A06Z&se=2021-05-28T07%3A52%3A06Z&sp=r',
#   'logs/azureml/sidecar/tvmps_33c03fa3f303a2d67271aba56f1f519b11dc078dcc42c7912f8d653f76fe6343_d/all.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622158971_1f171416/logs/azureml/sidecar/tvmps_33c03fa3f303a2d67271aba56f1f519b11dc078dcc42c7912f8d653f76fe6343_d/all.log?sv=2019-02-02&sr=b&sig=mGWzLEtiLYAToD4RqMQEpDwbdqYrukPxVStBj5ZJsU8%3D&st=2021-05-27T23%3A42%3A06Z&se=2021-05-28T07%3A52%3A06Z&sp=r',
#   'logs/azureml/sidecar/tvmps_33c03fa3f303a2d67271aba56f1f519b11dc078dcc42c7912f8d653f76fe6343_d/task.enter_contexts.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622158971_1f171416/logs/azureml/sidecar/tvmps_33c03fa3f303a2d67271aba56f1f519b11dc078dcc42c7912f8d653f76fe6343_d/task.enter_contexts.log?sv=2019-02-02&sr=b&sig=wr2aDZoq2yoWypOZmgSw9vU4sbheRwyXMbVuJyA5ljo%3D&st=2021-05-27T23%3A42%3A06Z&se=2021-05-28T07%3A52%3A06Z&sp=r',
#   'logs/azureml/sidecar/tvmps_33c03fa3f303a2d67271aba56f1f519b11dc078dcc42c7912f8d653f76fe6343_d/task.exit_contexts.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622158971_1f171416/logs/azureml/sidecar/tvmps_33c03fa3f303a2d67271aba56f1f519b11dc078dcc42c7912f8d653f76fe6343_d/task.exit_contexts.log?sv=2019-02-02&sr=b&sig=B%2FARl%2FDl33Poyga1Dnh1TgxfUmGgJeiVH5ksOTX6XA4%3D&st=2021-05-27T23%3A42%3A06Z&se=2021-05-28T07%3A52%3A06Z&sp=r'},
#  'submittedBy': 'Daniel Chen'}
