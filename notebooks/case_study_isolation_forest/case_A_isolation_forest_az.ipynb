# %%
## SET UP AZUREML DETAILS
# imports
from azureml.core.authentication import InteractiveLoginAuthentication
from azureml.core import Workspace, Environment, Experiment, Dataset, ScriptRunConfig

# set up workspace
config_path = '../../utils/config_GPU.json'
tenant_id = '72f988bf-86f1-41af-91ab-2d7cd011db47'  # this is outputted post `az login`
interactive_auth = InteractiveLoginAuthentication(tenant_id=tenant_id)  # create log-in object
ws = Workspace.from_config(path=config_path, auth=interactive_auth)  # link workspace

# set up environment
# - obtain environment.yml from `conda env export > environment.yml`
env_name = 'SampleEnv'
env_path = '../../utils/environment.yml'
env = Environment.from_conda_specification(name=env_name, file_path=env_path)

# set up experiment
experiment_name = 'AnomalyDetection'
exp = Experiment(workspace=ws, name=experiment_name)

# set up dataset
dataset_path = 'http://kdd.ics.uci.edu/databases/kddcup99/kddcup.data_10_percent.gz'
ds = Dataset.File.from_files(dataset_path)

# set up run
src_dir = '../../src/case_study_isolation_forest'
src_name = 'azure_isolation_forest_case_A.py'
compute_name = 'gpu-compute-one'
arguments = ['--data-path', ds.as_mount()]
src = ScriptRunConfig(source_directory=src_dir, script=src_name, compute_target=compute_name,
                      environment=env, arguments=arguments)
# Out:
# Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.

# %%
## SUBMIT THE RUN
from azureml.widgets import RunDetails

run = exp.submit(src)  # submit it to the azureml platform
RunDetails(run).show()  # monitor the steps
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…

# %%
# show the outputs
run.wait_for_completion(show_output=True)
# Out:
# RunId: AnomalyDetection_1622154982_7f4c2bd3
# Web View: https://ml.azure.com/experiments/AnomalyDetection/runs/AnomalyDetection_1622154982_7f4c2bd3?wsid=/subscriptions/92c76a2f-0e1c-4216-b65e-abf7a3f34c1e/resourcegroups/AzureML_UW_NLP/workspaces/AZ_ML
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2021/05/27 22:36:38 Downloading source code...
# 2021/05/27 22:36:39 Finished downloading source code
# 2021/05/27 22:36:39 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/05/27 22:36:40 Successfully set up Docker network: acb_default_network
# 2021/05/27 22:36:40 Setting up Docker configuration...
# 2021/05/27 22:36:41 Successfully set up Docker configuration
# 2021/05/27 22:36:41 Logging in to registry: 81d5da74a7444ffbbe3ed0ec060119d5.azurecr.io
# 2021/05/27 22:36:42 Successfully logged into 81d5da74a7444ffbbe3ed0ec060119d5.azurecr.io
# 2021/05/27 22:36:42 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/27 22:36:42 Scanning for dependencies...
# 2021/05/27 22:36:43 Successfully scanned dependencies
# 2021/05/27 22:36:43 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210129.v1@sha256:19fe6a6202757242643beace8d3d690519f431deb21adc072989185425a22133
# mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210129.v1@sha256:19fe6a6202757242643beace8d3d690519f431deb21adc072989185425a22133: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# 4007a89234b4: Already exists
# 5dfa26c6b9c9: Already exists
# 0ba7bf18aa40: Already exists
# 4c6ec688ebe3: Already exists
# a358e5622b47: Pulling fs layer
# b68b2629181d: Pulling fs layer
# b40419bab046: Pulling fs layer
# 30e069d8e198: Pulling fs layer
# a82e4e12442c: Pulling fs layer
# 1bb969deda78: Pulling fs layer
# 85856583f10d: Pulling fs layer
# 103fa978967f: Pulling fs layer
# 30e069d8e198: Waiting
# a82e4e12442c: Waiting
# 1bb969deda78: Waiting
# 85856583f10d: Waiting
# b40419bab046: Verifying Checksum
# b40419bab046: Download complete
# b68b2629181d: Verifying Checksum
# b68b2629181d: Download complete
# a358e5622b47: Verifying Checksum
# a358e5622b47: Download complete
# 30e069d8e198: Verifying Checksum
# 30e069d8e198: Download complete
# 1bb969deda78: Verifying Checksum
# 1bb969deda78: Download complete
# 103fa978967f: Verifying Checksum
# 103fa978967f: Download complete
# 85856583f10d: Verifying Checksum
# 85856583f10d: Download complete
# a358e5622b47: Pull complete
# b68b2629181d: Pull complete
# b40419bab046: Pull complete
# a82e4e12442c: Verifying Checksum
# a82e4e12442c: Download complete
# 30e069d8e198: Pull complete
# a82e4e12442c: Pull complete
# 1bb969deda78: Pull complete
# 85856583f10d: Pull complete
# 103fa978967f: Pull complete
# Digest: sha256:19fe6a6202757242643beace8d3d690519f431deb21adc072989185425a22133
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210129.v1@sha256:19fe6a6202757242643beace8d3d690519f431deb21adc072989185425a22133
#  ---> faddb90bd04e
# Step 2/18 : USER root
#  ---> Running in 742be610212f
# Removing intermediate container 742be610212f
#  ---> 648df1c34291
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in 1b98386c6e24
# Removing intermediate container 1b98386c6e24
#  ---> 6489c123948c
# Step 4/18 : WORKDIR /
#  ---> Running in b026c167d3d2
# Removing intermediate container b026c167d3d2
#  ---> c7927441916a
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 3fa007e7592b
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 7700d3b1a579
# Removing intermediate container 7700d3b1a579
#  ---> 1f47e6be8cb5
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> b0376501c3d6
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_85d71eb43e0985ef03c127d2ca5e6476 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 416599f4ad58
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# ca-certificates-2021 | 114 KB    |            |   0%
# ca-certificates-2021 | 114 KB    | ########## | 100%
#
# openssl-1.1.1k       | 2.5 MB    |            |   0%
# openssl-1.1.1k       | 2.5 MB    | ########## | 100%
#
# tk-8.6.10            | 3.0 MB    |            |   0%
# tk-8.6.10            | 3.0 MB    | ########## | 100%
#
# libffi-3.3           | 50 KB     |            |   0%
# libffi-3.3           | 50 KB     | ########## | 100%
#
# readline-8.1         | 362 KB    |            |   0%
# readline-8.1         | 362 KB    | ########## | 100%
#
# wheel-0.36.2         | 33 KB     |            |   0%
# wheel-0.36.2         | 33 KB     | ########## | 100%
#
# pip-21.1.1           | 1.8 MB    |            |   0%
# pip-21.1.1           | 1.8 MB    | ########## | 100%
#
# sqlite-3.35.4        | 981 KB    |            |   0%
# sqlite-3.35.4        | 981 KB    | ########## | 100%
#
# certifi-2020.12.5    | 141 KB    |            |   0%
# certifi-2020.12.5    | 141 KB    | ########## | 100%
#
# xz-5.2.5             | 341 KB    |            |   0%
# xz-5.2.5             | 341 KB    | ########## | 100%
#
# zlib-1.2.11          | 103 KB    |            |   0%
# zlib-1.2.11          | 103 KB    | ########## | 100%
#
# python-3.8.10        | 50.1 MB   |            |   0%
# python-3.8.10        | 50.1 MB   | #2         |  13%
# python-3.8.10        | 50.1 MB   | ##8        |  28%
# python-3.8.10        | 50.1 MB   | ####4      |  45%
# python-3.8.10        | 50.1 MB   | ######1    |  61%
# python-3.8.10        | 50.1 MB   | #######6   |  77%
# python-3.8.10        | 50.1 MB   | #########2 |  93%
# python-3.8.10        | 50.1 MB   | ########## | 100%
#
# libgcc-ng-9.1.0      | 5.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 5.1 MB    | ########## | 100%
#
# setuptools-52.0.0    | 714 KB    |            |   0%
# setuptools-52.0.0    | 714 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 3.1 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 3.1 MB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# ld_impl_linux-64-2.3 | 568 KB    |            |   0%
# ld_impl_linux-64-2.3 | 568 KB    | ########## | 100%
#
# ncurses-6.2          | 817 KB    |            |   0%
# ncurses-6.2          | 817 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_85d71eb43e0985ef03c127d2ca5e6476/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.7c95bii3.requirements.txt']
# Pip subprocess output:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting anomatools
#   Downloading anomatools-2.3.0-py3-none-any.whl (25 kB)
# Collecting dtaidistance
#   Downloading dtaidistance-2.2.5.tar.gz (932 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting azureml-dataprep
#   Downloading azureml_dataprep-2.17.0-py3-none-any.whl (39.4 MB)
# Collecting azureml-mlflow
#   Downloading azureml_mlflow-1.29.0-py3-none-any.whl (41 kB)
# Collecting mlflow
#   Downloading mlflow-1.17.0-py3-none-any.whl (14.2 MB)
# Collecting matplotlib
#   Downloading matplotlib-3.4.2-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
# Collecting seaborn
#   Downloading seaborn-0.11.1-py3-none-any.whl (285 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-0.24.2-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
# Collecting numpy>=1.13.3
#   Downloading numpy-1.20.3-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.4 MB)
# Collecting scipy>=0.19.1
#   Downloading scipy-1.6.3-cp38-cp38-manylinux1_x86_64.whl (27.2 MB)
# Requirement already satisfied: setuptools>=41.6.0 in /azureml-envs/azureml_85d71eb43e0985ef03c127d2ca5e6476/lib/python3.8/site-packages (from anomatools->-r /azureml-environment-setup/condaenv.7c95bii3.requirements.txt (line 2)) (52.0.0.post20210125)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting joblib>=0.11
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
# Collecting cython>=0.29.6
#   Using cached Cython-0.29.23-cp38-cp38-manylinux1_x86_64.whl (1.9 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting azureml-dataprep-native<36.0.0,>=35.0.0
#   Downloading azureml_dataprep_native-35.0.0-cp38-cp38-manylinux1_x86_64.whl (1.4 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-rslex<1.16.0a,>=1.15.0dev0
#   Downloading azureml_dataprep_rslex-1.15.0-cp38-cp38-manylinux1_x86_64.whl (84.0 MB)
# Collecting cryptography>=2.1.4
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.12.0-py2.py3-none-any.whl (66 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.14.0-py2.py3-none-any.whl (136 kB)
# Collecting six>=1.6
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting requests>=2.18.4
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.5-cp38-cp38-manylinux1_x86_64.whl (411 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting PyJWT[crypto]<3,>=1.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_85d71eb43e0985ef03c127d2ca5e6476/lib/python3.8/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.0.0->azure-identity<1.5.0,>=1.2.0->azureml-dataprep->-r /azureml-environment-setup/condaenv.7c95bii3.requirements.txt (line 4)) (2020.12.5)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.5-py2.py3-none-any.whl (138 kB)
# Collecting azureml-core~=1.29.0
#   Downloading azureml_core-1.29.0-py3-none-any.whl (2.2 MB)
# Collecting mlflow-skinny
#   Downloading mlflow_skinny-1.17.0-py3-none-any.whl (547 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.0.0-py2.py3-none-any.whl (663 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting python-dateutil<3.0.0,>=2.7.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting contextlib2<1.0.0
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting pytz
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting ruamel.yaml<1.0.0,>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting docker<5.0.0
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.2.2-py2.py3-none-any.whl (21 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.0.1-py2.py3-none-any.whl (68 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Downloading ruamel.yaml.clib-0.2.2-cp38-cp38-manylinux1_x86_64.whl (578 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting databricks-cli>=0.8.7
#   Downloading databricks-cli-0.14.3.tar.gz (54 kB)
# Collecting pandas
#   Downloading pandas-1.2.4-cp38-cp38-manylinux1_x86_64.whl (9.7 MB)
# Collecting gitpython>=2.1.0
#   Downloading GitPython-3.1.17-py3-none-any.whl (166 kB)
# Collecting sqlparse>=0.3.1
#   Downloading sqlparse-0.4.1-py3-none-any.whl (42 kB)
# Collecting protobuf>=3.6.0
#   Downloading protobuf-3.17.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Collecting querystring-parser
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting alembic<=1.4.1
#   Downloading alembic-1.4.1.tar.gz (1.1 MB)
# Collecting gunicorn
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting prometheus-flask-exporter
#   Downloading prometheus_flask_exporter-0.18.2.tar.gz (22 kB)
# Collecting entrypoints
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting click>=7.0
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
# Collecting sqlalchemy
#   Downloading SQLAlchemy-1.4.15-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
# Collecting pyyaml
#   Downloading PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl (662 kB)
# Collecting Flask
#   Downloading Flask-2.0.1-py3-none-any.whl (94 kB)
# Collecting Mako
#   Downloading Mako-1.1.4-py2.py3-none-any.whl (75 kB)
# Collecting python-editor>=0.3
#   Downloading python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Collecting tabulate>=0.7.7
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
# Collecting smmap<5,>=3.0.1
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-1.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (164 kB)
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.2.0-cp38-cp38-manylinux1_x86_64.whl (3.0 MB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp38-cp38-manylinux1_x86_64.whl (1.2 MB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting Jinja2>=3.0
#   Downloading Jinja2-3.0.1-py3-none-any.whl (133 kB)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting Werkzeug>=2.0
#   Downloading Werkzeug-2.0.1-py3-none-any.whl (288 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp38-cp38-manylinux2010_x86_64.whl (30 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting prometheus_client
#   Downloading prometheus_client-0.10.1-py2.py3-none-any.whl (55 kB)
# Building wheels for collected packages: sklearn, dtaidistance, alembic, databricks-cli, prometheus-flask-exporter
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=95ab5b9b0838cbaf55bf4c362b0dcbffbdc14ca4aae6465d8b1ccc3a642be0c0
#   Stored in directory: /root/.cache/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
#   Building wheel for dtaidistance (PEP 517): started
#   Building wheel for dtaidistance (PEP 517): finished with status 'done'
#   Created wheel for dtaidistance: filename=dtaidistance-2.2.5-cp38-cp38-linux_x86_64.whl size=1650546 sha256=d7608466ccb879975aafd2d8ff063704f9a239f5dc4e1878536ae2f7188658f2
#   Stored in directory: /root/.cache/pip/wheels/65/38/f0/3ddff21151e88aac5f62fc024b877c0091abd3381e64760d53
#   Building wheel for alembic (setup.py): started
#   Building wheel for alembic (setup.py): finished with status 'done'
#   Created wheel for alembic: filename=alembic-1.4.1-py2.py3-none-any.whl size=158155 sha256=37198894d36e91d49eecae37eaaf661cc37b01bf4da38292001504d6a2a40cef
#   Stored in directory: /root/.cache/pip/wheels/9d/de/6d/ca8d461ec29e010b1267d7353d0b058819770f7680bb9360e4
#   Building wheel for databricks-cli (setup.py): started
#   Building wheel for databricks-cli (setup.py): finished with status 'done'
#   Created wheel for databricks-cli: filename=databricks_cli-0.14.3-py3-none-any.whl size=100555 sha256=e9bbaf8221c1b74fc9eaca2497931930d5b20b25c15627fb9c25571cd131b749
#   Stored in directory: /root/.cache/pip/wheels/e9/f3/dc/eeff77dbc147629fa716741fc216520abbc0e15ce4b876706f
#   Building wheel for prometheus-flask-exporter (setup.py): started
#   Building wheel for prometheus-flask-exporter (setup.py): finished with status 'done'
#   Created wheel for prometheus-flask-exporter: filename=prometheus_flask_exporter-0.18.2-py3-none-any.whl size=17399 sha256=88faf534bad0577e897315871f2f4f3f684b83e881a27ec35f3a38dfbdc8efb5
#   Stored in directory: /root/.cache/pip/wheels/69/6f/b4/2087abb1172ae32c58e366dc09746de46a72b0e9fb2c022920
# Successfully built sklearn dtaidistance alembic databricks-cli prometheus-flask-exporter
# Installing collected packages: urllib3, pycparser, idna, chardet, six, requests, oauthlib, cffi, requests-oauthlib, python-dateutil, PyJWT, isodate, cryptography, smmap, msrest, MarkupSafe, azure-core, adal, Werkzeug, websocket-client, tabulate, ruamel.yaml.clib, pyopenssl, pyasn1, portalocker, numpy, msrestazure, msal, Jinja2, jeepney, itsdangerous, greenlet, gitdb, click, backports.weakref, azure-mgmt-core, azure-common, threadpoolctl, sqlalchemy, SecretStorage, scipy, ruamel.yaml, pyyaml, pytz, python-editor, pyparsing, protobuf, prometheus-client, pillow, pathspec, ndg-httpsclient, msal-extensions, Mako, kiwisolver, jsonpickle, joblib, jmespath, gitpython, Flask, entrypoints, docker, distro, databricks-cli, cycler, contextlib2, cloudpickle, backports.tempfile, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, sqlparse, scikit-learn, querystring-parser, prometheus-flask-exporter, pandas, mlflow-skinny, matplotlib, gunicorn, dotnetcore2, cython, azureml-dataprep-rslex, azureml-dataprep-native, azureml-core, azure-identity, alembic, sklearn, seaborn, mlflow, dtaidistance, azureml-mlflow, azureml-dataprep, anomatools
# Successfully installed Flask-2.0.1 Jinja2-3.0.1 Mako-1.1.4 MarkupSafe-2.0.1 PyJWT-2.1.0 SecretStorage-3.3.1 Werkzeug-2.0.1 adal-1.2.7 alembic-1.4.1 anomatools-2.3.0 azure-common-1.1.27 azure-core-1.14.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.0.0 azure-mgmt-core-1.2.2 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.29.0 azureml-dataprep-2.17.0 azureml-dataprep-native-35.0.0 azureml-dataprep-rslex-1.15.0 azureml-mlflow-1.29.0 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.5 chardet-4.0.0 click-8.0.1 cloudpickle-1.6.0 contextlib2-0.6.0.post1 cryptography-3.4.7 cycler-0.10.0 cython-0.29.23 databricks-cli-0.14.3 distro-1.5.0 docker-4.4.4 dotnetcore2-2.1.20 dtaidistance-2.2.5 entrypoints-0.3 gitdb-4.0.7 gitpython-3.1.17 greenlet-1.1.0 gunicorn-20.1.0 idna-2.10 isodate-0.6.0 itsdangerous-2.0.1 jeepney-0.6.0 jmespath-0.10.0 joblib-1.0.1 jsonpickle-2.0.0 kiwisolver-1.3.1 matplotlib-3.4.2 mlflow-1.17.0 mlflow-skinny-1.17.0 msal-1.12.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 numpy-1.20.3 oauthlib-3.1.0 pandas-1.2.4 pathspec-0.8.1 pillow-8.2.0 portalocker-1.7.1 prometheus-client-0.10.1 prometheus-flask-exporter-0.18.2 protobuf-3.17.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 pyparsing-2.4.7 python-dateutil-2.8.1 python-editor-1.0.4 pytz-2021.1 pyyaml-5.4.1 querystring-parser-1.2.4 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.2 scikit-learn-0.24.2 scipy-1.6.3 seaborn-0.11.1 six-1.16.0 sklearn-0.0 smmap-4.0.0 sqlalchemy-1.4.15 sqlparse-0.4.1 tabulate-0.8.9 threadpoolctl-2.1.0 urllib3-1.26.5 websocket-client-1.0.1
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_85d71eb43e0985ef03c127d2ca5e6476
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 416599f4ad58
#  ---> 6a949392168d
# Step 9/18 : ENV PATH /azureml-envs/azureml_85d71eb43e0985ef03c127d2ca5e6476/bin:$PATH
#  ---> Running in 09d18f124a3c
# Removing intermediate container 09d18f124a3c
#  ---> 998abfa9abce
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> bfec7f40f64b
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 4f5eb090a883
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_85d71eb43e0985ef03c127d2ca5e6476
#  ---> Running in 7dd8e991097e
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 7dd8e991097e
#  ---> 6f20d8a98388
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_85d71eb43e0985ef03c127d2ca5e6476
#  ---> Running in f8662514b37b
# Removing intermediate container f8662514b37b
#  ---> 0fe52e224534
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_85d71eb43e0985ef03c127d2ca5e6476/lib:$LD_LIBRARY_PATH
#  ---> Running in 63df786571d9
# Removing intermediate container 63df786571d9
#  ---> f8b73e94389a
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> cc3e37f69b34
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 9f7d7da08f90
# Removing intermediate container 9f7d7da08f90
#  ---> 0f75d23db1ed
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in c08ee6739c84
# Removing intermediate container c08ee6739c84
#  ---> fa403ce98b90
# Step 18/18 : CMD ["bash"]
#  ---> Running in e6b26e1462aa
# Removing intermediate container e6b26e1462aa
#  ---> 616a03c59541
# Successfully built 616a03c59541
# Successfully tagged 81d5da74a7444ffbbe3ed0ec060119d5.azurecr.io/azureml/azureml_e09bfaa27865cae0196655c08e040dc7:latest
# Successfully tagged 81d5da74a7444ffbbe3ed0ec060119d5.azurecr.io/azureml/azureml_e09bfaa27865cae0196655c08e040dc7:2
# 2021/05/27 22:41:24 Successfully executed container: acb_step_0
# 2021/05/27 22:41:24 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/27 22:41:24 Pushing image: 81d5da74a7444ffbbe3ed0ec060119d5.azurecr.io/azureml/azureml_e09bfaa27865cae0196655c08e040dc7:2, attempt 1
# The push refers to repository [81d5da74a7444ffbbe3ed0ec060119d5.azurecr.io/azureml/azureml_e09bfaa27865cae0196655c08e040dc7]
# 1ad81a72e208: Preparing
# 83625d876eec: Preparing
# f24022fa9f20: Preparing
# da82fabb852d: Preparing
# 560b7a9b1883: Preparing
# 59b290921cd9: Preparing
# c431d0913a41: Preparing
# b39c1b1466be: Preparing
# 2b1bb6cc45f4: Preparing
# 11a33be78ee4: Preparing
# 7e92ccffb921: Preparing
# 7bd1885661f8: Preparing
# cfbdd4b09eb1: Preparing
# 1279e1c526b8: Preparing
# eb152233bfcc: Preparing
# 1bd2431681e9: Preparing
# f4424f38afe7: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# 59b290921cd9: Waiting
# c431d0913a41: Waiting
# b39c1b1466be: Waiting
# 2b1bb6cc45f4: Waiting
# 11a33be78ee4: Waiting
# 7e92ccffb921: Waiting
# 7bd1885661f8: Waiting
# cfbdd4b09eb1: Waiting
# 1279e1c526b8: Waiting
# eb152233bfcc: Waiting
# 1bd2431681e9: Waiting
# f4424f38afe7: Waiting
# 5276d2b930fc: Waiting
# 697949baa658: Waiting
# 935c56d8b3f9: Waiting
# e6feec0db89a: Waiting
# 1ad81a72e208: Pushed
# da82fabb852d: Pushed
# f24022fa9f20: Pushed
# 83625d876eec: Pushed
# b39c1b1466be: Pushed
# 59b290921cd9: Pushed
# c431d0913a41: Pushed
# 2b1bb6cc45f4: Pushed
# 11a33be78ee4: Layer already exists
# 7e92ccffb921: Layer already exists
# 7bd1885661f8: Layer already exists
# 1bd2431681e9: Layer already exists
#
# eb152233bfcc: Pushed
# 5276d2b930fc: Layer already exists
# e6feec0db89a: Layer already exists
# 697949baa658: Layer already exists
# 1279e1c526b8: Pushed
# cfbdd4b09eb1: Pushed
# f4424f38afe7: Pushed
# 935c56d8b3f9: Pushed
# 560b7a9b1883: Pushed
# 2: digest: sha256:cb824b62b62ae9ef7b8f0490e38f222379afe417f0ef543663a5d8fc2f1aaac1 size: 4721
# 2021/05/27 22:43:32 Successfully pushed image: 81d5da74a7444ffbbe3ed0ec060119d5.azurecr.io/azureml/azureml_e09bfaa27865cae0196655c08e040dc7:2
# 2021/05/27 22:43:32 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/27 22:43:32 Pushing image: 81d5da74a7444ffbbe3ed0ec060119d5.azurecr.io/azureml/azureml_e09bfaa27865cae0196655c08e040dc7:latest, attempt 1
# The push refers to repository [81d5da74a7444ffbbe3ed0ec060119d5.azurecr.io/azureml/azureml_e09bfaa27865cae0196655c08e040dc7]
# 1ad81a72e208: Preparing
# 83625d876eec: Preparing
# f24022fa9f20: Preparing
# da82fabb852d: Preparing
# 560b7a9b1883: Preparing
# 59b290921cd9: Preparing
# c431d0913a41: Preparing
# b39c1b1466be: Preparing
# 2b1bb6cc45f4: Preparing
# 11a33be78ee4: Preparing
# 7e92ccffb921: Preparing
# 7bd1885661f8: Preparing
# cfbdd4b09eb1: Preparing
# 1279e1c526b8: Preparing
# eb152233bfcc: Preparing
# 1bd2431681e9: Preparing
# f4424f38afe7: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# cfbdd4b09eb1: Waiting
# 1279e1c526b8: Waiting
# eb152233bfcc: Waiting
# 1bd2431681e9: Waiting
# f4424f38afe7: Waiting
# 5276d2b930fc: Waiting
# e6feec0db89a: Waiting
# 697949baa658: Waiting
# 59b290921cd9: Waiting
# 935c56d8b3f9: Waiting
# 11a33be78ee4: Waiting
# c431d0913a41: Waiting
# 7e92ccffb921: Waiting
# b39c1b1466be: Waiting
# 2b1bb6cc45f4: Waiting
# 7bd1885661f8: Waiting
# 83625d876eec: Layer already exists
# da82fabb852d: Layer already exists
# 560b7a9b1883: Layer already exists
# f24022fa9f20: Layer already exists
# 59b290921cd9: Layer already exists
# 1ad81a72e208: Layer already exists
# 11a33be78ee4: Layer already exists
# c431d0913a41: Layer already exists
# b39c1b1466be: Layer already exists
# 7e92ccffb921: Layer already exists
# 2b1bb6cc45f4: Layer already exists
# cfbdd4b09eb1: Layer already exists
# 7bd1885661f8: Layer already exists
# 1279e1c526b8: Layer already exists
# 1bd2431681e9: Layer already exists
# eb152233bfcc: Layer already exists
# 5276d2b930fc: Layer already exists
# f4424f38afe7: Layer already exists
# e6feec0db89a: Layer already exists
# 935c56d8b3f9: Layer already exists
# 697949baa658: Layer already exists
# latest: digest: sha256:cb824b62b62ae9ef7b8f0490e38f222379afe417f0ef543663a5d8fc2f1aaac1 size: 4721
# 2021/05/27 22:43:34 Successfully pushed image: 81d5da74a7444ffbbe3ed0ec060119d5.azurecr.io/azureml/azureml_e09bfaa27865cae0196655c08e040dc7:latest
# 2021/05/27 22:43:34 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 281.354105)
# 2021/05/27 22:43:34 Populating digests for step ID: acb_step_0...
# 2021/05/27 22:43:38 Successfully populated digests for step ID: acb_step_0
# 2021/05/27 22:43:38 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 128.727428)
# 2021/05/27 22:43:38 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.530971)
# 2021/05/27 22:43:38 The following dependencies were found:
# 2021/05/27 22:43:38
# - image:
#     registry: 81d5da74a7444ffbbe3ed0ec060119d5.azurecr.io
#     repository: azureml/azureml_e09bfaa27865cae0196655c08e040dc7
#     tag: latest
#     digest: sha256:cb824b62b62ae9ef7b8f0490e38f222379afe417f0ef543663a5d8fc2f1aaac1
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210129.v1
#     digest: sha256:19fe6a6202757242643beace8d3d690519f431deb21adc072989185425a22133
#   git: {}
# - image:
#     registry: 81d5da74a7444ffbbe3ed0ec060119d5.azurecr.io
#     repository: azureml/azureml_e09bfaa27865cae0196655c08e040dc7
#     tag: "2"
#     digest: sha256:cb824b62b62ae9ef7b8f0490e38f222379afe417f0ef543663a5d8fc2f1aaac1
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210129.v1
#     digest: sha256:19fe6a6202757242643beace8d3d690519f431deb21adc072989185425a22133
#   git: {}
#
# Run ID: cf2 was successful after 7m2s
#
# Streaming azureml-logs/65_job_prep-tvmps_4ccdcb232d8c09892fc32d4024795d61f679107d0a236c3c3564f1063d081af9_p.txt
# ===============================================================================================================
#
# [2021-05-27T22:46:53.943206] Entering job preparation.
# [2021-05-27T22:46:54.464474] Starting job preparation.
# [2021-05-27T22:46:54.464500] Extracting the control code.
# [2021-05-27T22:46:54.478233] fetching and extracting the control code on master node.
# [2021-05-27T22:46:54.478251] Starting extract_project.
# [2021-05-27T22:46:54.478280] Starting to extract zip file.
# [2021-05-27T22:46:54.882426] Finished extracting zip file.
# [2021-05-27T22:46:55.044139] Using urllib.request Python 3.0 or later
# [2021-05-27T22:46:55.044168] Start fetching snapshots.
# [2021-05-27T22:46:55.044193] Start fetching snapshot.
# [2021-05-27T22:46:55.044205] Retrieving project from snapshot: 54729061-d180-42ec-90a9-aa5a428c93de
# Starting the daemon thread to refresh tokens in background for process with pid = 51
# [2021-05-27T22:46:55.472964] Finished fetching snapshot.
# [2021-05-27T22:46:55.472978] Finished fetching snapshots.
# [2021-05-27T22:46:55.472988] Finished extract_project.
# [2021-05-27T22:46:55.481542] Finished fetching and extracting the control code.
# [2021-05-27T22:46:55.485934] Start run_history_prep.
# [2021-05-27T22:46:55.530398] Job preparation is complete.
# [2021-05-27T22:46:55.530493] Entering Data Context Managers in Sidecar
# [2021-05-27T22:46:55.531003] Running Sidecar prep cmd...
# [2021-05-27T22:46:55.864894] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/az_ml/azureml/anomalydetection_1622154982_7f4c2bd3/mounts/workspaceblobstore/azureml/AnomalyDetection_1622154982_7f4c2bd3
# [2021-05-27T22:46:55.865536] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.28.0 azureml-dataprep==2.16.0. Session id: 8550bf6f-bc26-4110-ba91-aa2cc67587c2. Run id: AnomalyDetection_1622154982_7f4c2bd3.
# Processing 'input__d3e18715'.
# Processing dataset FileDataset
# {
#   "source": [
#     "http://kdd.ics.uci.edu/databases/kddcup99/kddcup.data_10_percent.gz"
#   ],
#   "definition": [
#     "GetFiles"
#   ],
#   "registration": {
#     "id": "fb35714e-4e3e-4096-8b08-6ce08fc320c1",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='AZ_ML', subscription_id='92c76a2f-0e1c-4216-b65e-abf7a3f34c1e', resource_group='AzureML_UW_NLP')"
#   }
# }
# Mounting input__d3e18715 to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/az_ml/azureml/anomalydetection_1622154982_7f4c2bd3/wd/input__d3e18715_fb35714e-4e3e-4096-8b08-6ce08fc320c1.
# Mounted input__d3e18715 to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/az_ml/azureml/anomalydetection_1622154982_7f4c2bd3/wd/input__d3e18715_fb35714e-4e3e-4096-8b08-6ce08fc320c1 as single file.
# Exit __enter__ of DatasetContextManager
# Set Dataset input__d3e18715's target path to /mnt/batch/tasks/shared/LS_root/jobs/az_ml/azureml/anomalydetection_1622154982_7f4c2bd3/wd/input__d3e18715_fb35714e-4e3e-4096-8b08-6ce08fc320c1/kddcup.data_10_percent.gz
# [2021-05-27T22:47:02.548779] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-05-27T22:47:03.007042] Ran Sidecar prep cmd.
# [2021-05-27T22:47:03.007105] Running Context Managers in Sidecar complete.
# Streaming azureml-logs/75_job_post-tvmps_4ccdcb232d8c09892fc32d4024795d61f679107d0a236c3c3564f1063d081af9_p.txt
# ===============================================================================================================
#
# [2021-05-27T22:47:40.937236] Entering job release
# [2021-05-27T22:47:41.953213] Starting job release
# [2021-05-27T22:47:41.953741] Logging experiment finalizing status in history service.
# [2021-05-27T22:47:41.953907] job release stage : upload_datastore starting...Starting the daemon thread to refresh tokens in background for process with pid = 316
# [2021-05-27T22:47:41.954416] job release stage : start importing azureml.history._tracking in run_history_release.
#
# [2021-05-27T22:47:41.954627] job release stage : execute_job_release starting...[2021-05-27T22:47:41.954852] job release stage : copy_batchai_cached_logs starting...
#
# [2021-05-27T22:47:41.956596] job release stage : copy_batchai_cached_logs completed...
# [2021-05-27T22:47:42.005095] Entering context manager injector.
# [2021-05-27T22:47:42.044338] job release stage : send_run_telemetry starting...
# [2021-05-27T22:47:42.045218] job release stage : upload_datastore completed...
# [2021-05-27T22:47:42.056713] job release stage : execute_job_release completed...
# [2021-05-27T22:47:42.220785] get vm size and vm region successfully.
# [2021-05-27T22:47:42.232293] get compute meta data successfully.
# [2021-05-27T22:47:42.510357] post artifact meta request successfully.
# [2021-05-27T22:47:42.529889] upload compute record artifact successfully.
# [2021-05-27T22:47:42.529952] job release stage : send_run_telemetry completed...
# [2021-05-27T22:47:42.530249] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-05-27T22:47:42.530478] Running Sidecar release cmd...
# [2021-05-27T22:47:42.545024] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/az_ml/azureml/anomalydetection_1622154982_7f4c2bd3/mounts/workspaceblobstore/azureml/AnomalyDetection_1622154982_7f4c2bd3
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/az_ml/azureml/anomalydetection_1622154982_7f4c2bd3/wd/input__d3e18715_fb35714e-4e3e-4096-8b08-6ce08fc320c1.
# fuse: failed to unmount /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/az_ml/azureml/anomalydetection_1622154982_7f4c2bd3/wd/input__d3e18715_fb35714e-4e3e-4096-8b08-6ce08fc320c1: Invalid argument
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/az_ml/azureml/anomalydetection_1622154982_7f4c2bd3/wd/input__d3e18715_fb35714e-4e3e-4096-8b08-6ce08fc320c1.
# Exit __exit__ of DatasetContextManager
# [2021-05-27T22:47:42.595830] Removing absolute paths from host...
# [2021-05-27T22:47:42.607871] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-05-27T22:47:43.295808] Ran Sidecar release cmd.
# [2021-05-27T22:47:43.295879] Job release is complete
#
# Execution Summary
# =================
# RunId: AnomalyDetection_1622154982_7f4c2bd3
# Web View: https://ml.azure.com/experiments/AnomalyDetection/runs/AnomalyDetection_1622154982_7f4c2bd3?wsid=/subscriptions/92c76a2f-0e1c-4216-b65e-abf7a3f34c1e/resourcegroups/AzureML_UW_NLP/workspaces/AZ_ML
# {'runId': 'AnomalyDetection_1622154982_7f4c2bd3',
#  'target': 'gpu-compute-one',
#  'status': 'Completed',
#  'startTimeUtc': '2021-05-27T22:46:30.912429Z',
#  'endTimeUtc': '2021-05-27T22:47:52.043016Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': 'ab5c4e46-f036-4577-b108-4285a0643c50',
#   'azureml.git.repository_uri': 'https://github.com/danielgchen/MS_AZML_Anomaly_Detection.git',
#   'mlflow.source.git.repoURL': 'https://github.com/danielgchen/MS_AZML_Anomaly_Detection.git',
#   'azureml.git.branch': 'master',
#   'mlflow.source.git.branch': 'master',
#   'azureml.git.commit': '462d3f28acee8b4e44f9d33ad513084a9d4360b5',
#   'mlflow.source.git.commit': '462d3f28acee8b4e44f9d33ad513084a9d4360b5',
#   'azureml.git.dirty': 'True',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json',
#   'mlflow.param.key.bootstrap': 'False',
#   'mlflow.param.key.contamination': 'auto',
#   'mlflow.param.key.max_features': '50',
#   'mlflow.param.key.max_samples': '256',
#   'mlflow.param.key.n_estimators': '500',
#   'mlflow.param.key.n_jobs': 'None',
#   'mlflow.param.key.random_state': '0',
#   'mlflow.param.key.verbose': '0',
#   'mlflow.param.key.warm_start': 'False'},
#  'inputDatasets': [{'dataset': {'id': 'fb35714e-4e3e-4096-8b08-6ce08fc320c1'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input__d3e18715', 'mechanism': 'Mount'}}],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'azure_isolation_forest_case_A.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--data-path', 'DatasetConsumptionConfig:input__d3e18715'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'gpu-compute-one',
#   'dataReferences': {},
#   'data': {'input__d3e18715': {'dataLocation': {'dataset': {'id': 'fb35714e-4e3e-4096-8b08-6ce08fc320c1',
#       'name': None,
#       'version': None},
#      'dataPath': None,
#      'uri': None},
#     'mechanism': 'Mount',
#     'environmentVariableName': 'input__d3e18715',
#     'pathOnCompute': None,
#     'overwrite': False}},
#   'outputData': {},
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'SampleEnv',
#    'version': 'Autosave_2021-05-27T22:36:25Z_43ef3656',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['defaults', 'anaconda', 'conda-forge'],
#      'dependencies': ['python=3.8',
#       'pip',
#       {'pip': ['sklearn',
#         'anomatools',
#         'dtaidistance',
#         'azureml-dataprep',
#         'azureml-mlflow',
#         'mlflow',
#         'matplotlib',
#         'seaborn']}],
#      'name': 'azureml_85d71eb43e0985ef03c127d2ca5e6476'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210129.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'dockerContext': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': None,
#    'imageVersion': None,
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {}},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://azmlstorageeb99611c07bd4.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622154982_7f4c2bd3/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=cMj5wKDDkhHpO998rYJtnbzg8fBzsMOAl948YQF6CzY%3D&st=2021-05-27T22%3A37%3A58Z&se=2021-05-28T06%3A47%3A58Z&sp=r',
#   'azureml-logs/55_azureml-execution-tvmps_4ccdcb232d8c09892fc32d4024795d61f679107d0a236c3c3564f1063d081af9_p.txt': 'https://azmlstorageeb99611c07bd4.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622154982_7f4c2bd3/azureml-logs/55_azureml-execution-tvmps_4ccdcb232d8c09892fc32d4024795d61f679107d0a236c3c3564f1063d081af9_p.txt?sv=2019-02-02&sr=b&sig=NETRaD4DULiF2kBMgPOwGkEMGjAu1pvWP1epp%2B%2FOXJA%3D&st=2021-05-27T22%3A37%3A58Z&se=2021-05-28T06%3A47%3A58Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_4ccdcb232d8c09892fc32d4024795d61f679107d0a236c3c3564f1063d081af9_p.txt': 'https://azmlstorageeb99611c07bd4.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622154982_7f4c2bd3/azureml-logs/65_job_prep-tvmps_4ccdcb232d8c09892fc32d4024795d61f679107d0a236c3c3564f1063d081af9_p.txt?sv=2019-02-02&sr=b&sig=RcjUOR%2Fvj%2FypBo1oExW6CB5L5x2bUO0sxwDKQula%2BPw%3D&st=2021-05-27T22%3A37%3A58Z&se=2021-05-28T06%3A47%3A58Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://azmlstorageeb99611c07bd4.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622154982_7f4c2bd3/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=41pyeSSstJDmNLV3B0%2Bc5WyuwuaLHHyHKiNYfzu7CCI%3D&st=2021-05-27T22%3A37%3A58Z&se=2021-05-28T06%3A47%3A58Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_4ccdcb232d8c09892fc32d4024795d61f679107d0a236c3c3564f1063d081af9_p.txt': 'https://azmlstorageeb99611c07bd4.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622154982_7f4c2bd3/azureml-logs/75_job_post-tvmps_4ccdcb232d8c09892fc32d4024795d61f679107d0a236c3c3564f1063d081af9_p.txt?sv=2019-02-02&sr=b&sig=eKuPACJHlTTNBdgjrBa%2Fwax4jR8U3EJcdqBHVp%2FMA68%3D&st=2021-05-27T22%3A37%3A58Z&se=2021-05-28T06%3A47%3A58Z&sp=r',
#   'azureml-logs/process_info.json': 'https://azmlstorageeb99611c07bd4.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622154982_7f4c2bd3/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=FAjCrSc4Dezc1vS7ogEIxLMgSzSbxgNNrcMO9n8%2Frbs%3D&st=2021-05-27T22%3A37%3A58Z&se=2021-05-28T06%3A47%3A58Z&sp=r',
#   'azureml-logs/process_status.json': 'https://azmlstorageeb99611c07bd4.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622154982_7f4c2bd3/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=%2F0GoqtL%2B1qTt0PH1c98SVRl4hkewuf%2FV8pGubnq7yiA%3D&st=2021-05-27T22%3A37%3A58Z&se=2021-05-28T06%3A47%3A58Z&sp=r',
#   'logs/azureml/84_azureml.log': 'https://azmlstorageeb99611c07bd4.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622154982_7f4c2bd3/logs/azureml/84_azureml.log?sv=2019-02-02&sr=b&sig=igUWAMtG2IegtqkwBi4kMhtFVrhtynFztX8RSxhjZCQ%3D&st=2021-05-27T22%3A37%3A58Z&se=2021-05-28T06%3A47%3A58Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess.log': 'https://azmlstorageeb99611c07bd4.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622154982_7f4c2bd3/logs/azureml/dataprep/backgroundProcess.log?sv=2019-02-02&sr=b&sig=9o%2FDfcav3gniZCQjcNNKH88P8IYxwCFkTigzzoXxvjU%3D&st=2021-05-27T22%3A37%3A58Z&se=2021-05-28T06%3A47%3A58Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess_Telemetry.log': 'https://azmlstorageeb99611c07bd4.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622154982_7f4c2bd3/logs/azureml/dataprep/backgroundProcess_Telemetry.log?sv=2019-02-02&sr=b&sig=PWgj30DP%2FMHCxYbQ%2Bo80YIfhaYKyy8EvZtkpX1VrKtU%3D&st=2021-05-27T22%3A37%3A58Z&se=2021-05-28T06%3A47%3A58Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://azmlstorageeb99611c07bd4.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622154982_7f4c2bd3/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=nUxQizKHBcTOJ%2FJFpeANvtAkQfY%2BRmlq9FH6Igd2OQA%3D&st=2021-05-27T22%3A37%3A58Z&se=2021-05-28T06%3A47%3A58Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://azmlstorageeb99611c07bd4.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622154982_7f4c2bd3/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=11aOX3sJ3efhuPIaZ2lKUUi5YK2zG09%2FRS8uIu9t9wA%3D&st=2021-05-27T22%3A37%3A58Z&se=2021-05-28T06%3A47%3A58Z&sp=r',
#   'logs/azureml/sidecar/tvmps_4ccdcb232d8c09892fc32d4024795d61f679107d0a236c3c3564f1063d081af9_p/all.log': 'https://azmlstorageeb99611c07bd4.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622154982_7f4c2bd3/logs/azureml/sidecar/tvmps_4ccdcb232d8c09892fc32d4024795d61f679107d0a236c3c3564f1063d081af9_p/all.log?sv=2019-02-02&sr=b&sig=plId1JQpDeUZnfehbutr70d6akdOT%2BFbAHgXfX00J04%3D&st=2021-05-27T22%3A37%3A58Z&se=2021-05-28T06%3A47%3A58Z&sp=r',
#   'logs/azureml/sidecar/tvmps_4ccdcb232d8c09892fc32d4024795d61f679107d0a236c3c3564f1063d081af9_p/task.enter_contexts.log': 'https://azmlstorageeb99611c07bd4.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622154982_7f4c2bd3/logs/azureml/sidecar/tvmps_4ccdcb232d8c09892fc32d4024795d61f679107d0a236c3c3564f1063d081af9_p/task.enter_contexts.log?sv=2019-02-02&sr=b&sig=wB%2F1M1ivi2pxCvOPLmZB3u9IstQZYweHz%2FsZ8h6J7Oo%3D&st=2021-05-27T22%3A37%3A58Z&se=2021-05-28T06%3A47%3A58Z&sp=r',
#   'logs/azureml/sidecar/tvmps_4ccdcb232d8c09892fc32d4024795d61f679107d0a236c3c3564f1063d081af9_p/task.exit_contexts.log': 'https://azmlstorageeb99611c07bd4.blob.core.windows.net/azureml/ExperimentRun/dcid.AnomalyDetection_1622154982_7f4c2bd3/logs/azureml/sidecar/tvmps_4ccdcb232d8c09892fc32d4024795d61f679107d0a236c3c3564f1063d081af9_p/task.exit_contexts.log?sv=2019-02-02&sr=b&sig=095e1h6wtN%2BL43Ez1R2SzYYVAyTaswLnTMpin14pnGI%3D&st=2021-05-27T22%3A37%3A58Z&se=2021-05-28T06%3A47%3A58Z&sp=r'},
#  'submittedBy': 'Daniel Chen'}
